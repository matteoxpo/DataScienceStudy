# %% [markdown]
# # Вариант 1

# %%
import pandas as pd

# %%
data = pd.read_csv('NSTU_Students_data.csv')
data.head(5)
# Out:
#        Пол                Направление подготовки Курс обучения  \
# 0  Мужской  Информатика и вычислительная техника           NaN
# 1  Женский   Биотехнические системы и технологии           NaN
# 2  Женский  Информатика и вычислительная техника           NaN
# 3  Мужской           Информационная безопасность           NaN
# 4  Мужской   Информационные системы и технологии           NaN
#
#   Сумма баллов ЕГЭ за 3 предмета  \
# 0                        231-260
# 1                        201-230
# 2                        201-230
# 3                        151-200
# 4                        231-260
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                         Математика
# 1                                         Математика
# 2                                                NaN
# 3                                         Математика
# 4                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                     Информатика и программирование
# 1                                                NaN
# 2                                                NaN
# 3                     Информатика и программирование
# 4                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                                NaN
# 1                                             Физика
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                    Геймдев, VR, AR
#
#   Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                              Спорт
# 1                                              Спорт
# 2                                                NaN
# 3                                              Спорт
# 4                                              Спорт
#
#   Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                   Программирование
# 1                                                NaN
# 2                                                NaN
# 3                                   Программирование
# 4                                                NaN
#
#    ... Насколько вы любите заниматься ...? / Биологией  \
# 0  ...                        Меня это мало интересует
# 1  ...                         Да, это точно про меня!
# 2  ...                        Меня это мало интересует
# 3  ...                         Да, это точно про меня!
# 4  ...                        Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                            Да, это точно про меня!
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                            Да, это точно про меня!
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                               Затрудняюсь ответить
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                               Затрудняюсь ответить
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                               Затрудняюсь ответить
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                               Затрудняюсь ответить
# 4                           Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0        Искусственный интеллект и машинное обучение
# 1        Искусственный интеллект и машинное обучение
# 2                               Мобильная разработка
# 3                                  Кибербезопасность
# 4                                     QA-тестировщик
#
#   Вы поступили в университет, потому что сами этого хотели?  \
# 0                                                 Да
# 1                                                 Да
# 2                                                 Да
# 3                                                 Да
# 4                                                 Да
#
#   Вам важно получать хорошие отметки?
# 0                                  Да
# 1                                  Да
# 2                                 Нет
# 3                                  Да
# 4                                  Да
#
# [5 rows x 29 columns]

# %%
import numpy as np

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# Преобразуем поля с полом вместо мужской/женский на 1/0 и другие бинарные поля

# %%
binary_fields = {
    'Пол': {'Мужской': True, 'Женский': False},
    'Вы поступили в университет, потому что сами этого хотели?': {'Да': True, 'Нет': False},
    'Вам важно получать хорошие отметки?': {'Да': True, 'Нет': False}
}

for field, mapping in binary_fields.items():
    data[field] = data[field].map(mapping)
data.head(5)
# Out:
#      Пол                Направление подготовки Курс обучения  \
# 0   True  Информатика и вычислительная техника           NaN
# 1  False   Биотехнические системы и технологии           NaN
# 2  False  Информатика и вычислительная техника           NaN
# 3   True           Информационная безопасность           NaN
# 4   True   Информационные системы и технологии           NaN
#
#   Сумма баллов ЕГЭ за 3 предмета  \
# 0                        231-260
# 1                        201-230
# 2                        201-230
# 3                        151-200
# 4                        231-260
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                         Математика
# 1                                         Математика
# 2                                                NaN
# 3                                         Математика
# 4                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                     Информатика и программирование
# 1                                                NaN
# 2                                                NaN
# 3                     Информатика и программирование
# 4                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                                NaN
# 1                                             Физика
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                    Геймдев, VR, AR
#
#   Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                              Спорт
# 1                                              Спорт
# 2                                                NaN
# 3                                              Спорт
# 4                                              Спорт
#
#   Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                   Программирование
# 1                                                NaN
# 2                                                NaN
# 3                                   Программирование
# 4                                                NaN
#
#    ... Насколько вы любите заниматься ...? / Биологией  \
# 0  ...                        Меня это мало интересует
# 1  ...                         Да, это точно про меня!
# 2  ...                        Меня это мало интересует
# 3  ...                         Да, это точно про меня!
# 4  ...                        Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                            Да, это точно про меня!
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                            Да, это точно про меня!
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                               Затрудняюсь ответить
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                               Затрудняюсь ответить
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                               Затрудняюсь ответить
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                               Затрудняюсь ответить
# 4                           Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0        Искусственный интеллект и машинное обучение
# 1        Искусственный интеллект и машинное обучение
# 2                               Мобильная разработка
# 3                                  Кибербезопасность
# 4                                     QA-тестировщик
#
#   Вы поступили в университет, потому что сами этого хотели?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Вам важно получать хорошие отметки?
# 0                                True
# 1                                True
# 2                               False
# 3                                True
# 4                                True
#
# [5 rows x 29 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#        Пол                Направление подготовки Курс обучения  \
# 0     True  Информатика и вычислительная техника           NaN
# 1    False   Биотехнические системы и технологии           NaN
# 2    False  Информатика и вычислительная техника           NaN
# 3     True           Информационная безопасность           NaN
# 4     True   Информационные системы и технологии           NaN
# ..     ...                                   ...           ...
# 421   True  Информатика и вычислительная техника        1 Курс
# 422   True   Биотехнические системы и технологии        1 Курс
# 423  False           Информационная безопасность        1 Курс
# 424   True   Информационные системы и технологии        1 Курс
# 425  False  Информатика и вычислительная техника        1 Курс
#
#     Сумма баллов ЕГЭ за 3 предмета  \
# 0                          231-260
# 1                          201-230
# 2                          201-230
# 3                          151-200
# 4                          231-260
# ..                             ...
# 421                        231-260
# 422                        201-230
# 423                        201-230
# 424                        231-260
# 425                        231-260
#
#     Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                           Математика
# 1                                           Математика
# 2                                                  NaN
# 3                                           Математика
# 4                                                  NaN
# ..                                                 ...
# 421                                                NaN
# 422                                         Математика
# 423                                                NaN
# 424                                         Математика
# 425                                                NaN
#
#     Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                       Информатика и программирование
# 1                                                  NaN
# 2                                                  NaN
# 3                       Информатика и программирование
# 4                                                  NaN
# ..                                                 ...
# 421                                                NaN
# 422                     Информатика и программирование
# 423                                                NaN
# 424                     Информатика и программирование
# 425                     Информатика и программирование
#
#     Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                                  NaN
# 1                                               Физика
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
# 424                                                NaN
# 425                                                NaN
#
#     Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                      Геймдев, VR, AR
# ..                                                 ...
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
# 424                                                NaN
# 425                                                NaN
#
#     Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                                Спорт
# 1                                                Спорт
# 2                                                  NaN
# 3                                                Спорт
# 4                                                Спорт
# ..                                                 ...
# 421                                              Спорт
# 422                                              Спорт
# 423                                                NaN
# 424                                                NaN
# 425                                                NaN
#
#     Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                     Программирование
# 1                                                  NaN
# 2                                                  NaN
# 3                                     Программирование
# 4                                                  NaN
# ..                                                 ...
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
# 424                                                NaN
# 425                                   Программирование
#
#      ... Насколько вы любите заниматься ...? / Биологией  \
# 0    ...                        Меня это мало интересует
# 1    ...                         Да, это точно про меня!
# 2    ...                        Меня это мало интересует
# 3    ...                         Да, это точно про меня!
# 4    ...                        Меня это мало интересует
# ..   ...                                             ...
# 421  ...                         Да, это точно про меня!
# 422  ...                         Да, это точно про меня!
# 423  ...                            Затрудняюсь ответить
# 424  ...                        Меня это мало интересует
# 425  ...                        Меня это мало интересует
#
#     Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                              Да, это точно про меня!
# 1                              Да, это точно про меня!
# 2                             Меня это мало интересует
# 3                              Да, это точно про меня!
# 4                                 Затрудняюсь ответить
# ..                                                 ...
# 421                           Меня это мало интересует
# 422                               Затрудняюсь ответить
# 423                           Меня это мало интересует
# 424                               Затрудняюсь ответить
# 425                            Да, это точно про меня!
#
#     Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                             Меня это мало интересует
# 1                                 Затрудняюсь ответить
# 2                             Меня это мало интересует
# 3                              Да, это точно про меня!
# 4                              Да, это точно про меня!
# ..                                                 ...
# 421                            Да, это точно про меня!
# 422                           Меня это мало интересует
# 423                               Затрудняюсь ответить
# 424                               Затрудняюсь ответить
# 425                           Меня это мало интересует
#
#     Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                              Да, это точно про меня!
# 1                                 Затрудняюсь ответить
# 2                              Да, это точно про меня!
# 3                                 Затрудняюсь ответить
# 4                                 Затрудняюсь ответить
# ..                                                 ...
# 421                           Меня это мало интересует
# 422                           Меня это мало интересует
# 423                               Затрудняюсь ответить
# 424                               Затрудняюсь ответить
# 425                            Да, это точно про меня!
#
#     Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                                 Затрудняюсь ответить
# 1                                 Затрудняюсь ответить
# 2                              Да, это точно про меня!
# 3                              Да, это точно про меня!
# 4                              Да, это точно про меня!
# ..                                                 ...
# 421                           Меня это мало интересует
# 422                           Меня это мало интересует
# 423                               Затрудняюсь ответить
# 424                            Да, это точно про меня!
# 425                           Меня это мало интересует
#
#     Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                                 Затрудняюсь ответить
# 1                              Да, это точно про меня!
# 2                             Меня это мало интересует
# 3                                 Затрудняюсь ответить
# 4                             Меня это мало интересует
# ..                                                 ...
# 421                               Затрудняюсь ответить
# 422                           Меня это мало интересует
# 423                           Меня это мало интересует
# 424                           Меня это мало интересует
# 425                           Меня это мало интересует
#
#     Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                             Меня это мало интересует
# 1                                 Затрудняюсь ответить
# 2                             Меня это мало интересует
# 3                              Да, это точно про меня!
# 4                              Да, это точно про меня!
# ..                                                 ...
# 421                               Затрудняюсь ответить
# 422                            Да, это точно про меня!
# 423                            Да, это точно про меня!
# 424                            Да, это точно про меня!
# 425                           Меня это мало интересует
#
#     Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0          Искусственный интеллект и машинное обучение
# 1          Искусственный интеллект и машинное обучение
# 2                                 Мобильная разработка
# 3                                    Кибербезопасность
# 4                                       QA-тестировщик
# ..                                                 ...
# 421                                     Разработка игр
# 422        Искусственный интеллект и машинное обучение
# 423                                  Кибербезопасность
# 424                         Системное программирование
# 425                                     Разработка игр
#
#     Вы поступили в университет, потому что сами этого хотели?  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 421                                               True
# 422                                              False
# 423                                               True
# 424                                               True
# 425                                               True
#
#     Вам важно получать хорошие отметки?
# 0                                  True
# 1                                  True
# 2                                 False
# 3                                  True
# 4                                  True
# ..                                  ...
# 421                                True
# 422                               False
# 423                                True
# 424                                True
# 425                                True
#
# [426 rows x 29 columns]

# %% [markdown]
# Преобразуем поле "Сумма баллов ЕГЭ за 3 предмета" в категории

# %%
data['Сумма баллов ЕГЭ за 3 предмета'].unique()
# Out:
# array(['231-260', '201-230', '151-200', '261-300', '120-150'],
#       dtype=object)

# %%
data.head(2)
# Out:
#      Пол                Направление подготовки Курс обучения  \
# 0   True  Информатика и вычислительная техника           NaN
# 1  False   Биотехнические системы и технологии           NaN
#
#   Сумма баллов ЕГЭ за 3 предмета  \
# 0                        231-260
# 1                        201-230
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                         Математика
# 1                                         Математика
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                     Информатика и программирование
# 1                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                                NaN
# 1                                             Физика
#
#   Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                NaN
# 1                                                NaN
#
#   Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                              Спорт
# 1                                              Спорт
#
#   Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                   Программирование
# 1                                                NaN
#
#    ... Насколько вы любите заниматься ...? / Биологией  \
# 0  ...                        Меня это мало интересует
# 1  ...                         Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                            Да, это точно про меня!
# 1                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                            Да, это точно про меня!
# 1                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                               Затрудняюсь ответить
# 1                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                               Затрудняюсь ответить
# 1                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
#
#   Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0        Искусственный интеллект и машинное обучение
# 1        Искусственный интеллект и машинное обучение
#
#   Вы поступили в университет, потому что сами этого хотели?  \
# 0                                               True
# 1                                               True
#
#   Вам важно получать хорошие отметки?
# 0                                True
# 1                                True
#
# [2 rows x 29 columns]

# %%
fields = {
    'Сумма баллов ЕГЭ за 3 предмета': {'120-150': 1, '151-200': 2, '201-230':3, '231-260': 4, '261-300': 5 }
}
for field, mapping in fields.items():
    data[field] = data[field].map(mapping)
data.head(5)
# Out:
#      Пол                Направление подготовки Курс обучения  \
# 0   True  Информатика и вычислительная техника           NaN
# 1  False   Биотехнические системы и технологии           NaN
# 2  False  Информатика и вычислительная техника           NaN
# 3   True           Информационная безопасность           NaN
# 4   True   Информационные системы и технологии           NaN
#
#    Сумма баллов ЕГЭ за 3 предмета  \
# 0                               4
# 1                               3
# 2                               3
# 3                               2
# 4                               4
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                         Математика
# 1                                         Математика
# 2                                                NaN
# 3                                         Математика
# 4                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                     Информатика и программирование
# 1                                                NaN
# 2                                                NaN
# 3                     Информатика и программирование
# 4                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                                NaN
# 1                                             Физика
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                    Геймдев, VR, AR
#
#   Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                              Спорт
# 1                                              Спорт
# 2                                                NaN
# 3                                              Спорт
# 4                                              Спорт
#
#   Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                   Программирование
# 1                                                NaN
# 2                                                NaN
# 3                                   Программирование
# 4                                                NaN
#
#    ... Насколько вы любите заниматься ...? / Биологией  \
# 0  ...                        Меня это мало интересует
# 1  ...                         Да, это точно про меня!
# 2  ...                        Меня это мало интересует
# 3  ...                         Да, это точно про меня!
# 4  ...                        Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                            Да, это точно про меня!
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                            Да, это точно про меня!
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                               Затрудняюсь ответить
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                               Затрудняюсь ответить
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                               Затрудняюсь ответить
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                               Затрудняюсь ответить
# 4                           Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0        Искусственный интеллект и машинное обучение
# 1        Искусственный интеллект и машинное обучение
# 2                               Мобильная разработка
# 3                                  Кибербезопасность
# 4                                     QA-тестировщик
#
#   Вы поступили в университет, потому что сами этого хотели?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Вам важно получать хорошие отметки?
# 0                                True
# 1                                True
# 2                               False
# 3                                True
# 4                                True
#
# [5 rows x 29 columns]

# %%
data['Сумма баллов ЕГЭ за 3 предмета'].mode()
# Out:
# 0    4
# Name: Сумма баллов ЕГЭ за 3 предмета, dtype: int64

# %%
data.tail(50)
# Out:
#        Пол                             Направление подготовки Курс обучения  \
# 376   True                Биотехнические системы и технологии        1 Курс
# 377   True                              Программная инженерия        3 Курс
# 378   True                Информационные системы и технологии        1 Курс
# 379  False               Информатика и вычислительная техника        1 Курс
# 380   True                  Управление в технических системах        1 Курс
# 381   True                  Управление в технических системах        1 Курс
# 382  False                  Управление в технических системах        1 Курс
# 383   True  Информационная безопасность автоматизированных...        1 Курс
# 384  False                Биотехнические системы и технологии        1 Курс
# 385   True               Информатика и вычислительная техника        1 Курс
# 386   True                Биотехнические системы и технологии        2 Курс
# 387  False                  Управление в технических системах        3 Курс
# 388   True                Биотехнические системы и технологии        1 Курс
# 389   True               Информатика и вычислительная техника        2 Курс
# 390   True                  Управление в технических системах        1 Курс
# 391   True               Информатика и вычислительная техника        2 Курс
# 392  False                              Программная инженерия        1 Курс
# 393   True                  Управление в технических системах        3 Курс
# 394   True                              Программная инженерия        3 Курс
# 395   True                  Управление в технических системах        1 Курс
# 396   True               Информатика и вычислительная техника        1 Курс
# 397   True                  Управление в технических системах        1 Курс
# 398  False               Информатика и вычислительная техника        1 Курс
# 399  False                Биотехнические системы и технологии        1 Курс
# 400   True                Информационные системы и технологии        2 Курс
# 401   True               Информатика и вычислительная техника        1 Курс
# 402   True                Информационные системы и технологии        1 Курс
# 403   True                Биотехнические системы и технологии        1 Курс
# 404  False                        Информационная безопасность        1 Курс
# 405   True  Информационная безопасность автоматизированных...        1 Курс
# 406   True                Биотехнические системы и технологии        1 Курс
# 407  False  Информационная безопасность автоматизированных...        1 Курс
# 408  False  Информационная безопасность автоматизированных...        1 Курс
# 409   True                Информационные системы и технологии        2 Курс
# 410  False                Информационные системы и технологии        1 Курс
# 411   True                                    Приборостроение        4 Курс
# 412   True                  Управление в технических системах        1 Курс
# 413   True  Информационная безопасность автоматизированных...        1 Курс
# 414  False  Информационная безопасность автоматизированных...        1 Курс
# 415   True  Информационная безопасность автоматизированных...        1 Курс
# 416   True                  Управление в технических системах        1 Курс
# 417   True                              Программная инженерия        1 Курс
# 418  False               Информатика и вычислительная техника        2 Курс
# 419   True  Информационная безопасность автоматизированных...        1 Курс
# 420   True               Информатика и вычислительная техника        1 Курс
# 421   True               Информатика и вычислительная техника        1 Курс
# 422   True                Биотехнические системы и технологии        1 Курс
# 423  False                        Информационная безопасность        1 Курс
# 424   True                Информационные системы и технологии        1 Курс
# 425  False               Информатика и вычислительная техника        1 Курс
#
#      Сумма баллов ЕГЭ за 3 предмета  \
# 376                               5
# 377                               4
# 378                               2
# 379                               1
# 380                               3
# 381                               4
# 382                               4
# 383                               2
# 384                               4
# 385                               5
# 386                               3
# 387                               3
# 388                               5
# 389                               4
# 390                               4
# 391                               4
# 392                               3
# 393                               3
# 394                               2
# 395                               3
# 396                               4
# 397                               3
# 398                               4
# 399                               3
# 400                               4
# 401                               2
# 402                               5
# 403                               3
# 404                               3
# 405                               3
# 406                               3
# 407                               4
# 408                               5
# 409                               3
# 410                               5
# 411                               3
# 412                               3
# 413                               3
# 414                               4
# 415                               3
# 416                               4
# 417                               2
# 418                               4
# 419                               4
# 420                               4
# 421                               4
# 422                               3
# 423                               3
# 424                               4
# 425                               4
#
#     Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                         Математика
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                                         Математика
# 384                                         Математика
# 385                                         Математика
# 386                                         Математика
# 387                                                NaN
# 388                                                NaN
# 389                                                NaN
# 390                                                NaN
# 391                                                NaN
# 392                                         Математика
# 393                                                NaN
# 394                                         Математика
# 395                                         Математика
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                                         Математика
# 401                                                NaN
# 402                                         Математика
# 403                                                NaN
# 404                                         Математика
# 405                                                NaN
# 406                                                NaN
# 407                                                NaN
# 408                                         Математика
# 409                                         Математика
# 410                                         Математика
# 411                                         Математика
# 412                                                NaN
# 413                                                NaN
# 414                                                NaN
# 415                                                NaN
# 416                                                NaN
# 417                                         Математика
# 418                                                NaN
# 419                                         Математика
# 420                                                NaN
# 421                                                NaN
# 422                                         Математика
# 423                                                NaN
# 424                                         Математика
# 425                                                NaN
#
#     Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                     Информатика и программирование
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                     Информатика и программирование
# 384                     Информатика и программирование
# 385                                                NaN
# 386                     Информатика и программирование
# 387                                                NaN
# 388                                                NaN
# 389                                                NaN
# 390                                                NaN
# 391                     Информатика и программирование
# 392                     Информатика и программирование
# 393                                                NaN
# 394                     Информатика и программирование
# 395                     Информатика и программирование
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                     Информатика и программирование
# 401                                                NaN
# 402                                                NaN
# 403                                                NaN
# 404                                                NaN
# 405                                                NaN
# 406                                                NaN
# 407                                                NaN
# 408                                                NaN
# 409                                                NaN
# 410                     Информатика и программирование
# 411                     Информатика и программирование
# 412                                                NaN
# 413                                                NaN
# 414                                                NaN
# 415                                                NaN
# 416                                                NaN
# 417                     Информатика и программирование
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                     Информатика и программирование
# 423                                                NaN
# 424                     Информатика и программирование
# 425                     Информатика и программирование
#
#     Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                                             Физика
# 384                                                NaN
# 385                                                NaN
# 386                                             Физика
# 387                                                NaN
# 388                                                NaN
# 389                                                NaN
# 390                                             Физика
# 391                                                NaN
# 392                                                NaN
# 393                                                NaN
# 394                                             Физика
# 395                                                NaN
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                                             Физика
# 401                                                NaN
# 402                                             Физика
# 403                                                NaN
# 404                                                NaN
# 405                                                NaN
# 406                                                NaN
# 407                                                NaN
# 408                                                NaN
# 409                                                NaN
# 410                                                NaN
# 411                                                NaN
# 412                                                NaN
# 413                                                NaN
# 414                                                NaN
# 415                                                NaN
# 416                                                NaN
# 417                                                NaN
# 418                                                NaN
# 419                                                NaN
# 420                                             Физика
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
# 424                                                NaN
# 425                                                NaN
#
#     Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                                                NaN
# 384                                                NaN
# 385                                    Геймдев, VR, AR
# 386                                                NaN
# 387                                                NaN
# 388                                                NaN
# 389                                                NaN
# 390                                                NaN
# 391                                                NaN
# 392                                    Геймдев, VR, AR
# 393                                                NaN
# 394                                                NaN
# 395                                    Геймдев, VR, AR
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
# 402                                                NaN
# 403                                    Геймдев, VR, AR
# 404                                                NaN
# 405                                                NaN
# 406                                                NaN
# 407                                                NaN
# 408                                                NaN
# 409                                    Геймдев, VR, AR
# 410                                                NaN
# 411                                                NaN
# 412                                                NaN
# 413                                                NaN
# 414                                                NaN
# 415                                                NaN
# 416                                                NaN
# 417                                    Геймдев, VR, AR
# 418                                                NaN
# 419                                                NaN
# 420                                    Геймдев, VR, AR
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
# 424                                                NaN
# 425                                                NaN
#
#     Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 376                                              Спорт
# 377                                              Спорт
# 378                                              Спорт
# 379                                                NaN
# 380                                                NaN
# 381                                              Спорт
# 382                                              Спорт
# 383                                                NaN
# 384                                              Спорт
# 385                                              Спорт
# 386                                              Спорт
# 387                                                NaN
# 388                                              Спорт
# 389                                                NaN
# 390                                                NaN
# 391                                              Спорт
# 392                                                NaN
# 393                                              Спорт
# 394                                              Спорт
# 395                                              Спорт
# 396                                              Спорт
# 397                                              Спорт
# 398                                                NaN
# 399                                              Спорт
# 400                                                NaN
# 401                                                NaN
# 402                                              Спорт
# 403                                                NaN
# 404                                              Спорт
# 405                                                NaN
# 406                                              Спорт
# 407                                              Спорт
# 408                                                NaN
# 409                                              Спорт
# 410                                              Спорт
# 411                                                NaN
# 412                                                NaN
# 413                                              Спорт
# 414                                                NaN
# 415                                              Спорт
# 416                                              Спорт
# 417                                                NaN
# 418                                                NaN
# 419                                              Спорт
# 420                                              Спорт
# 421                                              Спорт
# 422                                              Спорт
# 423                                                NaN
# 424                                                NaN
# 425                                                NaN
#
#     Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                   Программирование
# 380                                                NaN
# 381                                   Программирование
# 382                                   Программирование
# 383                                   Программирование
# 384                                   Программирование
# 385                                   Программирование
# 386                                                NaN
# 387                                   Программирование
# 388                                   Программирование
# 389                                                NaN
# 390                                                NaN
# 391                                   Программирование
# 392                                                NaN
# 393                                                NaN
# 394                                                NaN
# 395                                   Программирование
# 396                                   Программирование
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                                   Программирование
# 401                                   Программирование
# 402                                                NaN
# 403                                   Программирование
# 404                                   Программирование
# 405                                   Программирование
# 406                                                NaN
# 407                                   Программирование
# 408                                                NaN
# 409                                   Программирование
# 410                                                NaN
# 411                                                NaN
# 412                                                NaN
# 413                                   Программирование
# 414                                   Программирование
# 415                                   Программирование
# 416                                                NaN
# 417                                   Программирование
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
# 424                                                NaN
# 425                                   Программирование
#
#      ... Насколько вы любите заниматься ...? / Биологией  \
# 376  ...                            Затрудняюсь ответить
# 377  ...                            Затрудняюсь ответить
# 378  ...                        Меня это мало интересует
# 379  ...                         Да, это точно про меня!
# 380  ...                        Меня это мало интересует
# 381  ...                        Меня это мало интересует
# 382  ...                        Меня это мало интересует
# 383  ...                         Да, это точно про меня!
# 384  ...                            Затрудняюсь ответить
# 385  ...                            Затрудняюсь ответить
# 386  ...                            Затрудняюсь ответить
# 387  ...                            Затрудняюсь ответить
# 388  ...                         Да, это точно про меня!
# 389  ...                        Меня это мало интересует
# 390  ...                         Да, это точно про меня!
# 391  ...                        Меня это мало интересует
# 392  ...                        Меня это мало интересует
# 393  ...                         Да, это точно про меня!
# 394  ...                        Меня это мало интересует
# 395  ...                        Меня это мало интересует
# 396  ...                        Меня это мало интересует
# 397  ...                        Меня это мало интересует
# 398  ...                        Меня это мало интересует
# 399  ...                            Затрудняюсь ответить
# 400  ...                        Меня это мало интересует
# 401  ...                        Меня это мало интересует
# 402  ...                            Затрудняюсь ответить
# 403  ...                        Меня это мало интересует
# 404  ...                        Меня это мало интересует
# 405  ...                        Меня это мало интересует
# 406  ...                        Меня это мало интересует
# 407  ...                        Меня это мало интересует
# 408  ...                        Меня это мало интересует
# 409  ...                        Меня это мало интересует
# 410  ...                        Меня это мало интересует
# 411  ...                        Меня это мало интересует
# 412  ...                        Меня это мало интересует
# 413  ...                        Меня это мало интересует
# 414  ...                        Меня это мало интересует
# 415  ...                        Меня это мало интересует
# 416  ...                        Меня это мало интересует
# 417  ...                        Меня это мало интересует
# 418  ...                         Да, это точно про меня!
# 419  ...                        Меня это мало интересует
# 420  ...                        Меня это мало интересует
# 421  ...                         Да, это точно про меня!
# 422  ...                         Да, это точно про меня!
# 423  ...                            Затрудняюсь ответить
# 424  ...                        Меня это мало интересует
# 425  ...                        Меня это мало интересует
#
#     Насколько вы любите заниматься ...? / Аналитикой данных  \
# 376                           Меня это мало интересует
# 377                           Меня это мало интересует
# 378                            Да, это точно про меня!
# 379                           Меня это мало интересует
# 380                            Да, это точно про меня!
# 381                               Затрудняюсь ответить
# 382                               Затрудняюсь ответить
# 383                               Затрудняюсь ответить
# 384                           Меня это мало интересует
# 385                            Да, это точно про меня!
# 386                               Затрудняюсь ответить
# 387                               Затрудняюсь ответить
# 388                            Да, это точно про меня!
# 389                           Меня это мало интересует
# 390                               Затрудняюсь ответить
# 391                               Затрудняюсь ответить
# 392                           Меня это мало интересует
# 393                           Меня это мало интересует
# 394                           Меня это мало интересует
# 395                               Затрудняюсь ответить
# 396                           Меня это мало интересует
# 397                               Затрудняюсь ответить
# 398                            Да, это точно про меня!
# 399                           Меня это мало интересует
# 400                            Да, это точно про меня!
# 401                               Затрудняюсь ответить
# 402                            Да, это точно про меня!
# 403                            Да, это точно про меня!
# 404                            Да, это точно про меня!
# 405                               Затрудняюсь ответить
# 406                               Затрудняюсь ответить
# 407                            Да, это точно про меня!
# 408                           Меня это мало интересует
# 409                            Да, это точно про меня!
# 410                            Да, это точно про меня!
# 411                               Затрудняюсь ответить
# 412                           Меня это мало интересует
# 413                            Да, это точно про меня!
# 414                            Да, это точно про меня!
# 415                           Меня это мало интересует
# 416                               Затрудняюсь ответить
# 417                           Меня это мало интересует
# 418                            Да, это точно про меня!
# 419                               Затрудняюсь ответить
# 420                               Затрудняюсь ответить
# 421                           Меня это мало интересует
# 422                               Затрудняюсь ответить
# 423                           Меня это мало интересует
# 424                               Затрудняюсь ответить
# 425                            Да, это точно про меня!
#
#     Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 376                               Затрудняюсь ответить
# 377                            Да, это точно про меня!
# 378                           Меня это мало интересует
# 379                               Затрудняюсь ответить
# 380                           Меня это мало интересует
# 381                               Затрудняюсь ответить
# 382                               Затрудняюсь ответить
# 383                               Затрудняюсь ответить
# 384                            Да, это точно про меня!
# 385                            Да, это точно про меня!
# 386                               Затрудняюсь ответить
# 387                           Меня это мало интересует
# 388                           Меня это мало интересует
# 389                           Меня это мало интересует
# 390                           Меня это мало интересует
# 391                           Меня это мало интересует
# 392                            Да, это точно про меня!
# 393                           Меня это мало интересует
# 394                               Затрудняюсь ответить
# 395                               Затрудняюсь ответить
# 396                               Затрудняюсь ответить
# 397                               Затрудняюсь ответить
# 398                            Да, это точно про меня!
# 399                           Меня это мало интересует
# 400                            Да, это точно про меня!
# 401                           Меня это мало интересует
# 402                               Затрудняюсь ответить
# 403                               Затрудняюсь ответить
# 404                               Затрудняюсь ответить
# 405                            Да, это точно про меня!
# 406                               Затрудняюсь ответить
# 407                               Затрудняюсь ответить
# 408                            Да, это точно про меня!
# 409                           Меня это мало интересует
# 410                           Меня это мало интересует
# 411                           Меня это мало интересует
# 412                           Меня это мало интересует
# 413                           Меня это мало интересует
# 414                            Да, это точно про меня!
# 415                               Затрудняюсь ответить
# 416                           Меня это мало интересует
# 417                               Затрудняюсь ответить
# 418                           Меня это мало интересует
# 419                               Затрудняюсь ответить
# 420                               Затрудняюсь ответить
# 421                            Да, это точно про меня!
# 422                           Меня это мало интересует
# 423                               Затрудняюсь ответить
# 424                               Затрудняюсь ответить
# 425                           Меня это мало интересует
#
#     Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 376                           Меня это мало интересует
# 377                           Меня это мало интересует
# 378                           Меня это мало интересует
# 379                           Меня это мало интересует
# 380                           Меня это мало интересует
# 381                               Затрудняюсь ответить
# 382                               Затрудняюсь ответить
# 383                               Затрудняюсь ответить
# 384                               Затрудняюсь ответить
# 385                               Затрудняюсь ответить
# 386                               Затрудняюсь ответить
# 387                           Меня это мало интересует
# 388                               Затрудняюсь ответить
# 389                            Да, это точно про меня!
# 390                           Меня это мало интересует
# 391                           Меня это мало интересует
# 392                               Затрудняюсь ответить
# 393                           Меня это мало интересует
# 394                           Меня это мало интересует
# 395                               Затрудняюсь ответить
# 396                           Меня это мало интересует
# 397                            Да, это точно про меня!
# 398                               Затрудняюсь ответить
# 399                           Меня это мало интересует
# 400                            Да, это точно про меня!
# 401                            Да, это точно про меня!
# 402                               Затрудняюсь ответить
# 403                            Да, это точно про меня!
# 404                               Затрудняюсь ответить
# 405                            Да, это точно про меня!
# 406                            Да, это точно про меня!
# 407                               Затрудняюсь ответить
# 408                            Да, это точно про меня!
# 409                           Меня это мало интересует
# 410                            Да, это точно про меня!
# 411                            Да, это точно про меня!
# 412                           Меня это мало интересует
# 413                               Затрудняюсь ответить
# 414                               Затрудняюсь ответить
# 415                               Затрудняюсь ответить
# 416                            Да, это точно про меня!
# 417                               Затрудняюсь ответить
# 418                            Да, это точно про меня!
# 419                               Затрудняюсь ответить
# 420                               Затрудняюсь ответить
# 421                           Меня это мало интересует
# 422                           Меня это мало интересует
# 423                               Затрудняюсь ответить
# 424                               Затрудняюсь ответить
# 425                            Да, это точно про меня!
#
#     Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 376                           Меня это мало интересует
# 377                            Да, это точно про меня!
# 378                            Да, это точно про меня!
# 379                           Меня это мало интересует
# 380                           Меня это мало интересует
# 381                               Затрудняюсь ответить
# 382                               Затрудняюсь ответить
# 383                               Затрудняюсь ответить
# 384                               Затрудняюсь ответить
# 385                               Затрудняюсь ответить
# 386                               Затрудняюсь ответить
# 387                           Меня это мало интересует
# 388                               Затрудняюсь ответить
# 389                           Меня это мало интересует
# 390                           Меня это мало интересует
# 391                            Да, это точно про меня!
# 392                               Затрудняюсь ответить
# ...
# 408                           Меня это мало интересует
# 409                           Меня это мало интересует
# 410                               Затрудняюсь ответить
# 411                           Меня это мало интересует
# 412                            Да, это точно про меня!
# 413                           Меня это мало интересует
# 414                           Меня это мало интересует
# 415                               Затрудняюсь ответить
# 416                               Затрудняюсь ответить
# 417                           Меня это мало интересует
# 418                            Да, это точно про меня!
# 419                           Меня это мало интересует
# 420                               Затрудняюсь ответить
# 421                               Затрудняюсь ответить
# 422                           Меня это мало интересует
# 423                           Меня это мало интересует
# 424                           Меня это мало интересует
# 425                           Меня это мало интересует
#
#     Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 376                            Да, это точно про меня!
# 377                               Затрудняюсь ответить
# 378                               Затрудняюсь ответить
# 379                            Да, это точно про меня!
# 380                           Меня это мало интересует
# 381                               Затрудняюсь ответить
# 382                               Затрудняюсь ответить
# 383                               Затрудняюсь ответить
# 384                               Затрудняюсь ответить
# 385                            Да, это точно про меня!
# 386                               Затрудняюсь ответить
# 387                            Да, это точно про меня!
# 388                           Меня это мало интересует
# 389                           Меня это мало интересует
# 390                           Меня это мало интересует
# 391                           Меня это мало интересует
# 392                               Затрудняюсь ответить
# 393                           Меня это мало интересует
# 394                           Меня это мало интересует
# 395                            Да, это точно про меня!
# 396                           Меня это мало интересует
# 397                               Затрудняюсь ответить
# 398                            Да, это точно про меня!
# 399                           Меня это мало интересует
# 400                               Затрудняюсь ответить
# 401                            Да, это точно про меня!
# 402                               Затрудняюсь ответить
# 403                            Да, это точно про меня!
# 404                            Да, это точно про меня!
# 405                            Да, это точно про меня!
# 406                               Затрудняюсь ответить
# 407                               Затрудняюсь ответить
# 408                            Да, это точно про меня!
# 409                            Да, это точно про меня!
# 410                            Да, это точно про меня!
# 411                               Затрудняюсь ответить
# 412                           Меня это мало интересует
# 413                            Да, это точно про меня!
# 414                            Да, это точно про меня!
# 415                               Затрудняюсь ответить
# 416                           Меня это мало интересует
# 417                               Затрудняюсь ответить
# 418                           Меня это мало интересует
# 419                               Затрудняюсь ответить
# 420                               Затрудняюсь ответить
# 421                               Затрудняюсь ответить
# 422                            Да, это точно про меня!
# 423                            Да, это точно про меня!
# 424                            Да, это точно про меня!
# 425                           Меня это мало интересует
#
#     Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 376                                     Разработка игр
# 377                                     Разработка игр
# 378                                     Разработка игр
# 379        Искусственный интеллект и машинное обучение
# 380                                   Аналитика данных
# 381                         Системное программирование
# 382                       Облачные вычисления и DevOps
# 383                                     Разработка игр
# 384                                     Разработка игр
# 385                                     QA-тестировщик
# 386                                  Кибербезопасность
# 387                                     Разработка игр
# 388        Искусственный интеллект и машинное обучение
# 389                                     Веб-разработка
# 390                         Системное программирование
# 391                                     Разработка игр
# 392                                     Разработка игр
# 393                                     Разработка игр
# 394                                     Разработка игр
# 395        Искусственный интеллект и машинное обучение
# 396                               Мобильная разработка
# 397        Искусственный интеллект и машинное обучение
# 398                                     Разработка игр
# 399                                   Аналитика данных
# 400                                     Веб-разработка
# 401                                  Кибербезопасность
# 402                                   Аналитика данных
# 403                                  Кибербезопасность
# 404                                     QA-тестировщик
# 405                                     Разработка игр
# 406                                     Веб-разработка
# 407                                  Кибербезопасность
# 408                                     QA-тестировщик
# 409        Искусственный интеллект и машинное обучение
# 410                                   Аналитика данных
# 411        Искусственный интеллект и машинное обучение
# 412                               Мобильная разработка
# 413                                     Веб-разработка
# 414                                  Кибербезопасность
# 415                                  Кибербезопасность
# 416                         Системное программирование
# 417                                     Разработка игр
# 418                                   Аналитика данных
# 419                                     Разработка игр
# 420                         Системное программирование
# 421                                     Разработка игр
# 422        Искусственный интеллект и машинное обучение
# 423                                  Кибербезопасность
# 424                         Системное программирование
# 425                                     Разработка игр
#
#     Вы поступили в университет, потому что сами этого хотели?  \
# 376                                               True
# 377                                              False
# 378                                               True
# 379                                               True
# 380                                               True
# 381                                               True
# 382                                               True
# 383                                               True
# 384                                               True
# 385                                               True
# 386                                               True
# 387                                               True
# 388                                               True
# 389                                               True
# 390                                               True
# 391                                               True
# 392                                               True
# 393                                               True
# 394                                              False
# 395                                               True
# 396                                               True
# 397                                               True
# 398                                               True
# 399                                               True
# 400                                               True
# 401                                              False
# 402                                               True
# 403                                               True
# 404                                               True
# 405                                               True
# 406                                               True
# 407                                               True
# 408                                               True
# 409                                               True
# 410                                               True
# 411                                               True
# 412                                              False
# 413                                               True
# 414                                               True
# 415                                               True
# 416                                               True
# 417                                               True
# 418                                               True
# 419                                               True
# 420                                               True
# 421                                               True
# 422                                              False
# 423                                               True
# 424                                               True
# 425                                               True
#
#     Вам важно получать хорошие отметки?
# 376                                True
# 377                                True
# 378                                True
# 379                                True
# 380                                True
# 381                                True
# 382                                True
# 383                                True
# 384                                True
# 385                               False
# 386                               False
# 387                                True
# 388                                True
# 389                               False
# 390                                True
# 391                                True
# 392                                True
# 393                                True
# 394                               False
# 395                               False
# 396                                True
# 397                                True
# 398                                True
# 399                                True
# 400                               False
# 401                                True
# 402                                True
# 403                                True
# 404                               False
# 405                                True
# 406                                True
# 407                                True
# 408                                True
# 409                                True
# 410                                True
# 411                               False
# 412                               False
# 413                                True
# 414                                True
# 415                                True
# 416                                True
# 417                                True
# 418                                True
# 419                                True
# 420                                True
# 421                                True
# 422                               False
# 423                                True
# 424                                True
# 425                                True
#
# [50 rows x 29 columns]

# %%
data.head(2)
# Out:
#      Пол                Направление подготовки Курс обучения  \
# 0   True  Информатика и вычислительная техника           NaN
# 1  False   Биотехнические системы и технологии           NaN
#
#    Сумма баллов ЕГЭ за 3 предмета  \
# 0                               4
# 1                               3
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                         Математика
# 1                                         Математика
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                     Информатика и программирование
# 1                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                                NaN
# 1                                             Физика
#
#   Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                NaN
# 1                                                NaN
#
#   Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                              Спорт
# 1                                              Спорт
#
#   Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                   Программирование
# 1                                                NaN
#
#    ... Насколько вы любите заниматься ...? / Биологией  \
# 0  ...                        Меня это мало интересует
# 1  ...                         Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                            Да, это точно про меня!
# 1                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                            Да, это точно про меня!
# 1                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                               Затрудняюсь ответить
# 1                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                               Затрудняюсь ответить
# 1                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
#
#   Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0        Искусственный интеллект и машинное обучение
# 1        Искусственный интеллект и машинное обучение
#
#   Вы поступили в университет, потому что сами этого хотели?  \
# 0                                               True
# 1                                               True
#
#   Вам важно получать хорошие отметки?
# 0                                True
# 1                                True
#
# [2 rows x 29 columns]

# %% [markdown]
# Я забыл добавить вопрос о том на каком курсе человек учится! Надо заполнить Nan значения! Заодно переведем в числа

# %%
data['Курс обучения'] = data['Курс обучения'].fillna('4 Курс')
data.head(5)
# Out:
#      Пол                Направление подготовки Курс обучения  \
# 0   True  Информатика и вычислительная техника        4 Курс
# 1  False   Биотехнические системы и технологии        4 Курс
# 2  False  Информатика и вычислительная техника        4 Курс
# 3   True           Информационная безопасность        4 Курс
# 4   True   Информационные системы и технологии        4 Курс
#
#    Сумма баллов ЕГЭ за 3 предмета  \
# 0                               4
# 1                               3
# 2                               3
# 3                               2
# 4                               4
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                         Математика
# 1                                         Математика
# 2                                                NaN
# 3                                         Математика
# 4                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                     Информатика и программирование
# 1                                                NaN
# 2                                                NaN
# 3                     Информатика и программирование
# 4                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                                NaN
# 1                                             Физика
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                    Геймдев, VR, AR
#
#   Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                              Спорт
# 1                                              Спорт
# 2                                                NaN
# 3                                              Спорт
# 4                                              Спорт
#
#   Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                   Программирование
# 1                                                NaN
# 2                                                NaN
# 3                                   Программирование
# 4                                                NaN
#
#    ... Насколько вы любите заниматься ...? / Биологией  \
# 0  ...                        Меня это мало интересует
# 1  ...                         Да, это точно про меня!
# 2  ...                        Меня это мало интересует
# 3  ...                         Да, это точно про меня!
# 4  ...                        Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                            Да, это точно про меня!
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                            Да, это точно про меня!
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                               Затрудняюсь ответить
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                               Затрудняюсь ответить
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                               Затрудняюсь ответить
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                               Затрудняюсь ответить
# 4                           Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0        Искусственный интеллект и машинное обучение
# 1        Искусственный интеллект и машинное обучение
# 2                               Мобильная разработка
# 3                                  Кибербезопасность
# 4                                     QA-тестировщик
#
#   Вы поступили в университет, потому что сами этого хотели?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Вам важно получать хорошие отметки?
# 0                                True
# 1                                True
# 2                               False
# 3                                True
# 4                                True
#
# [5 rows x 29 columns]

# %%
fields = {
    'Курс обучения': {'1 Курс': 1, '2 Курс': 2, '3 Курс':3, '4 Курс': 4}
}
for field, mapping in fields.items():
    data[field] = data[field].map(mapping)
data.head(5)
# Out:
#      Пол                Направление подготовки  Курс обучения  \
# 0   True  Информатика и вычислительная техника              4
# 1  False   Биотехнические системы и технологии              4
# 2  False  Информатика и вычислительная техника              4
# 3   True           Информационная безопасность              4
# 4   True   Информационные системы и технологии              4
#
#    Сумма баллов ЕГЭ за 3 предмета  \
# 0                               4
# 1                               3
# 2                               3
# 3                               2
# 4                               4
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                         Математика
# 1                                         Математика
# 2                                                NaN
# 3                                         Математика
# 4                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                     Информатика и программирование
# 1                                                NaN
# 2                                                NaN
# 3                     Информатика и программирование
# 4                                                NaN
#
#   Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                                NaN
# 1                                             Физика
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                    Геймдев, VR, AR
#
#   Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                              Спорт
# 1                                              Спорт
# 2                                                NaN
# 3                                              Спорт
# 4                                              Спорт
#
#   Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                   Программирование
# 1                                                NaN
# 2                                                NaN
# 3                                   Программирование
# 4                                                NaN
#
#    ... Насколько вы любите заниматься ...? / Биологией  \
# 0  ...                        Меня это мало интересует
# 1  ...                         Да, это точно про меня!
# 2  ...                        Меня это мало интересует
# 3  ...                         Да, это точно про меня!
# 4  ...                        Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                            Да, это точно про меня!
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                            Да, это точно про меня!
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                               Затрудняюсь ответить
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                               Затрудняюсь ответить
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                               Затрудняюсь ответить
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                               Затрудняюсь ответить
# 4                           Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0        Искусственный интеллект и машинное обучение
# 1        Искусственный интеллект и машинное обучение
# 2                               Мобильная разработка
# 3                                  Кибербезопасность
# 4                                     QA-тестировщик
#
#   Вы поступили в университет, потому что сами этого хотели?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Вам важно получать хорошие отметки?
# 0                                True
# 1                                True
# 2                               False
# 3                                True
# 4                                True
#
# [5 rows x 29 columns]

# %% [markdown]
# Отлично! Теперь проработаем три по своему смыслу одинаковых поля! Зачем так?
# 'Принимали ли вы участие в олимпиадах по профильным предметам? / Математика',
# 'Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование',
# 'Принимали ли вы участие в олимпиадах по профильным предметам? / Физика'

# %%
olympiad_fields = [
    'Принимали ли вы участие в олимпиадах по профильным предметам? / Математика',
    'Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование',
    'Принимали ли вы участие в олимпиадах по профильным предметам? / Физика'
]

for field in olympiad_fields:
    data[field] = data[field].apply(lambda x: True if pd.notna(x) else False)
data.head(5)
# Out:
#      Пол                Направление подготовки  Курс обучения  \
# 0   True  Информатика и вычислительная техника              4
# 1  False   Биотехнические системы и технологии              4
# 2  False  Информатика и вычислительная техника              4
# 3   True           Информационная безопасность              4
# 4   True   Информационные системы и технологии              4
#
#    Сумма баллов ЕГЭ за 3 предмета  \
# 0                               4
# 1                               3
# 2                               3
# 3                               2
# 4                               4
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                              False
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                    Геймдев, VR, AR
#
#   Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                              Спорт
# 1                                              Спорт
# 2                                                NaN
# 3                                              Спорт
# 4                                              Спорт
#
#   Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                   Программирование
# 1                                                NaN
# 2                                                NaN
# 3                                   Программирование
# 4                                                NaN
#
#    ... Насколько вы любите заниматься ...? / Биологией  \
# 0  ...                        Меня это мало интересует
# 1  ...                         Да, это точно про меня!
# 2  ...                        Меня это мало интересует
# 3  ...                         Да, это точно про меня!
# 4  ...                        Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                            Да, это точно про меня!
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                            Да, это точно про меня!
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                               Затрудняюсь ответить
# 4                               Затрудняюсь ответить
#
#   Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                               Затрудняюсь ответить
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                               Затрудняюсь ответить
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                               Затрудняюсь ответить
# 4                           Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0        Искусственный интеллект и машинное обучение
# 1        Искусственный интеллект и машинное обучение
# 2                               Мобильная разработка
# 3                                  Кибербезопасность
# 4                                     QA-тестировщик
#
#   Вы поступили в университет, потому что сами этого хотели?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Вам важно получать хорошие отметки?
# 0                                True
# 1                                True
# 2                               False
# 3                                True
# 4                                True
#
# [5 rows x 29 columns]

# %% [markdown]
# По образу и подобию вопросы про школьные увлечения

# %%
hobbies_fields = [
    'Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR',
    'Какие увлечения у вас были, когда вы учились в школе? / Спорт',
    'Какие увлечения у вас были, когда вы учились в школе? / Программирование',
    'Какие увлечения у вас были, когда вы учились в школе? / Робототехника',
    'Какие увлечения у вас были, когда вы учились в школе? / 3D-моделирование',
    'Какие увлечения у вас были, когда вы учились в школе? / Решение математических задач',
    'Какие увлечения у вас были, когда вы учились в школе? / Творчество: музыка, рисование, танцы и т.п.',
    'Какие увлечения у вас были, когда вы учились в школе? / Физика',
]

for field in hobbies_fields:
    data[field] = data[field].apply(lambda x: True if pd.notna(x) else False)
data.head(5)
# Out:
#      Пол                Направление подготовки  Курс обучения  \
# 0   True  Информатика и вычислительная техника              4
# 1  False   Биотехнические системы и технологии              4
# 2  False  Информатика и вычислительная техника              4
# 3   True           Информационная безопасность              4
# 4   True   Информационные системы и технологии              4
#
#    Сумма баллов ЕГЭ за 3 предмета  \
# 0                               4
# 1                               3
# 2                               3
# 3                               2
# 4                               4
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                              False
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                               True
#
#    Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                               True
#
#    Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    ...  Насколько вы любите заниматься ...? / Биологией  \
# 0  ...                         Меня это мало интересует
# 1  ...                          Да, это точно про меня!
# 2  ...                         Меня это мало интересует
# 3  ...                          Да, это точно про меня!
# 4  ...                         Меня это мало интересует
#
#    Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                            Да, это точно про меня!
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                               Затрудняюсь ответить
#
#    Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#    Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                            Да, это точно про меня!
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                               Затрудняюсь ответить
# 4                               Затрудняюсь ответить
#
#    Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                               Затрудняюсь ответить
# 1                               Затрудняюсь ответить
# 2                            Да, это точно про меня!
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                               Затрудняюсь ответить
# 1                            Да, это точно про меня!
# 2                           Меня это мало интересует
# 3                               Затрудняюсь ответить
# 4                           Меня это мало интересует
#
#   Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                           Меня это мало интересует
# 1                               Затрудняюсь ответить
# 2                           Меня это мало интересует
# 3                            Да, это точно про меня!
# 4                            Да, это точно про меня!
#
#   Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0        Искусственный интеллект и машинное обучение
# 1        Искусственный интеллект и машинное обучение
# 2                               Мобильная разработка
# 3                                  Кибербезопасность
# 4                                     QA-тестировщик
#
#   Вы поступили в университет, потому что сами этого хотели?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Вам важно получать хорошие отметки?
# 0                                True
# 1                                True
# 2                               False
# 3                                True
# 4                                True
#
# [5 rows x 29 columns]

# %% [markdown]
# Теперь сложнее! - одинаковые ответы и разные вопоросы

# %%
opinion_mapping = {
    'Да, это точно про меня!': 3,
    'Затрудняюсь ответить': 2,
    'Меня это мало интересует': 1
}

for column in data.columns:
    if any(data[column].isin(opinion_mapping.keys())):
        data[column] = data[column].map(opinion_mapping)

data.head(5)
# Out:
#      Пол                Направление подготовки  Курс обучения  \
# 0   True  Информатика и вычислительная техника              4
# 1  False   Биотехнические системы и технологии              4
# 2  False  Информатика и вычислительная техника              4
# 3   True           Информационная безопасность              4
# 4   True   Информационные системы и технологии              4
#
#    Сумма баллов ЕГЭ за 3 предмета  \
# 0                               4
# 1                               3
# 2                               3
# 3                               2
# 4                               4
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                              False
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                               True
#
#    Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                               True
#
#    Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    ...  Насколько вы любите заниматься ...? / Биологией  \
# 0  ...                                                1
# 1  ...                                                3
# 2  ...                                                1
# 3  ...                                                3
# 4  ...                                                1
#
#    Насколько вы любите заниматься ...? / Аналитикой данных  \
# 0                                                  3
# 1                                                  3
# 2                                                  1
# 3                                                  3
# 4                                                  2
#
#    Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI  \
# 0                                                  1
# 1                                                  2
# 2                                                  1
# 3                                                  3
# 4                                                  3
#
#    Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  2
# 4                                                  2
#
#    Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    Насколько вы любите заниматься ...? / Экономикой и финансами  \
# 0                                                  2
# 1                                                  3
# 2                                                  1
# 3                                                  2
# 4                                                  1
#
#    Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях  \
# 0                                                  1
# 1                                                  2
# 2                                                  1
# 3                                                  3
# 4                                                  3
#
#    Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?  \
# 0        Искусственный интеллект и машинное обучение
# 1        Искусственный интеллект и машинное обучение
# 2                               Мобильная разработка
# 3                                  Кибербезопасность
# 4                                     QA-тестировщик
#
#    Вы поступили в университет, потому что сами этого хотели?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    Вам важно получать хорошие отметки?
# 0                                 True
# 1                                 True
# 2                                False
# 3                                 True
# 4                                 True
#
# [5 rows x 29 columns]

# %% [markdown]
# И остается разбить One-hot методом данные из выбора 1 сферы в IT

# %%
it_field = 'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?'
data = pd.get_dummies(data, columns=[it_field], prefix='', prefix_sep='')

data.head(5)
# Out:
#      Пол                Направление подготовки  Курс обучения  \
# 0   True  Информатика и вычислительная техника              4
# 1  False   Биотехнические системы и технологии              4
# 2  False  Информатика и вычислительная техника              4
# 3   True           Информационная безопасность              4
# 4   True   Информационные системы и технологии              4
#
#    Сумма баллов ЕГЭ за 3 предмета  \
# 0                               4
# 1                               3
# 2                               3
# 3                               2
# 4                               4
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                              False
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                               True
#
#    Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                               True
#
#    Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    ...  QA-тестировщик  Аналитика данных  Веб-разработка  \
# 0  ...           False             False           False
# 1  ...           False             False           False
# 2  ...           False             False           False
# 3  ...           False             False           False
# 4  ...            True             False           False
#
#    Искусственный интеллект и машинное обучение  Кибербезопасность  \
# 0                                         True              False
# 1                                         True              False
# 2                                        False              False
# 3                                        False               True
# 4                                        False              False
#
#    Мобильная разработка  Облачные вычисления и DevOps  Разработка UI/UX  \
# 0                 False                         False             False
# 1                 False                         False             False
# 2                  True                         False             False
# 3                 False                         False             False
# 4                 False                         False             False
#
#    Разработка игр  Системное программирование
# 0           False                       False
# 1           False                       False
# 2           False                       False
# 3           False                       False
# 4           False                       False
#
# [5 rows x 38 columns]

# %% [markdown]
# # Таргет
# Но у нас осталось поле, которое для нас является нашим таргетом, то, что мы хотим предугадывать

# %%
target = data['Направление подготовки']
print(type(target))
print(target.unique())
target
# Out:
# <class 'pandas.core.series.Series'>
# ['Информатика и вычислительная техника'
#  'Биотехнические системы и технологии' 'Информационная безопасность'
#  'Информационные системы и технологии'
#  'Информационная безопасность автоматизированных систем'
#  'Программная инженерия' 'Прикладная информатика'
#  'Управление в технических системах' 'Приборостроение']
# 0      Информатика и вычислительная техника
# 1       Биотехнические системы и технологии
# 2      Информатика и вычислительная техника
# 3               Информационная безопасность
# 4       Информационные системы и технологии
#                        ...
# 421    Информатика и вычислительная техника
# 422     Биотехнические системы и технологии
# 423             Информационная безопасность
# 424     Информационные системы и технологии
# 425    Информатика и вычислительная техника
# Name: Направление подготовки, Length: 426, dtype: object

# %%
data = data.drop(columns=['Направление подготовки'])
data.head(2)
# Out:
#      Пол  Курс обучения  Сумма баллов ЕГЭ за 3 предмета  \
# 0   True              4                               4
# 1  False              4                               3
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                               True
# 1                                               True
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                                               True
# 1                                              False
#
#    Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                              False
# 1                                               True
#
#    Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                              False
# 1                                              False
#
#    Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                               True
# 1                                               True
#
#    Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                               True
# 1                                              False
#
#    Какие увлечения у вас были, когда вы учились в школе? / Робототехника  ...  \
# 0                                              False                      ...
# 1                                              False                      ...
#
#    QA-тестировщик  Аналитика данных  Веб-разработка  \
# 0           False             False           False
# 1           False             False           False
#
#    Искусственный интеллект и машинное обучение  Кибербезопасность  \
# 0                                         True              False
# 1                                         True              False
#
#    Мобильная разработка  Облачные вычисления и DevOps  Разработка UI/UX  \
# 0                 False                         False             False
# 1                 False                         False             False
#
#    Разработка игр  Системное программирование
# 0           False                       False
# 1           False                       False
#
# [2 rows x 37 columns]

# %% [markdown]
# # Итого

# %%
data
# Out:
#        Пол  Курс обучения  Сумма баллов ЕГЭ за 3 предмета  \
# 0     True              4                               4
# 1    False              4                               3
# 2    False              4                               3
# 3     True              4                               2
# 4     True              4                               4
# ..     ...            ...                             ...
# 421   True              1                               4
# 422   True              1                               3
# 423  False              1                               3
# 424   True              1                               4
# 425  False              1                               4
#
#      Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                                 True
# 1                                                 True
# 2                                                False
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 421                                              False
# 422                                               True
# 423                                              False
# 424                                               True
# 425                                              False
#
#      Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                                                 True
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 421                                              False
# 422                                               True
# 423                                              False
# 424                                               True
# 425                                               True
#
#      Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                                False
# 1                                                 True
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 421                                              False
# 422                                              False
# 423                                              False
# 424                                              False
# 425                                              False
#
#      Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 421                                              False
# 422                                              False
# 423                                              False
# 424                                              False
# 425                                              False
#
#      Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                                 True
# 1                                                 True
# 2                                                False
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 421                                               True
# 422                                               True
# 423                                              False
# 424                                              False
# 425                                              False
#
#      Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                                 True
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 421                                              False
# 422                                              False
# 423                                              False
# 424                                              False
# 425                                               True
#
#      Какие увлечения у вас были, когда вы учились в школе? / Робототехника  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 421                                              False
# 422                                              False
# 423                                              False
# 424                                              False
# 425                                              False
#
#      ...  QA-тестировщик  Аналитика данных  Веб-разработка  \
# 0    ...           False             False           False
# 1    ...           False             False           False
# 2    ...           False             False           False
# 3    ...           False             False           False
# 4    ...            True             False           False
# ..   ...             ...               ...             ...
# 421  ...           False             False           False
# 422  ...           False             False           False
# 423  ...           False             False           False
# 424  ...           False             False           False
# 425  ...           False             False           False
#
#      Искусственный интеллект и машинное обучение  Кибербезопасность  \
# 0                                           True              False
# 1                                           True              False
# 2                                          False              False
# 3                                          False               True
# 4                                          False              False
# ..                                           ...                ...
# 421                                        False              False
# 422                                         True              False
# 423                                        False               True
# 424                                        False              False
# 425                                        False              False
#
#      Мобильная разработка  Облачные вычисления и DevOps  Разработка UI/UX  \
# 0                   False                         False             False
# 1                   False                         False             False
# 2                    True                         False             False
# 3                   False                         False             False
# 4                   False                         False             False
# ..                    ...                           ...               ...
# 421                 False                         False             False
# 422                 False                         False             False
# 423                 False                         False             False
# 424                 False                         False             False
# 425                 False                         False             False
#
#      Разработка игр  Системное программирование
# 0             False                       False
# 1             False                       False
# 2             False                       False
# 3             False                       False
# 4             False                       False
# ..              ...                         ...
# 421            True                       False
# 422           False                       False
# 423           False                       False
# 424           False                        True
# 425            True                       False
#
# [426 rows x 37 columns]

# %%
target
# Out:
# 0      Информатика и вычислительная техника
# 1       Биотехнические системы и технологии
# 2      Информатика и вычислительная техника
# 3               Информационная безопасность
# 4       Информационные системы и технологии
#                        ...
# 421    Информатика и вычислительная техника
# 422     Биотехнические системы и технологии
# 423             Информационная безопасность
# 424     Информационные системы и технологии
# 425    Информатика и вычислительная техника
# Name: Направление подготовки, Length: 426, dtype: object

# %% [markdown]
# Склеем для сохранения

# %%
data['target'] = target

# %%
data
# Out:
#        Пол  Курс обучения  Сумма баллов ЕГЭ за 3 предмета  \
# 0     True              4                               4
# 1    False              4                               3
# 2    False              4                               3
# 3     True              4                               2
# 4     True              4                               4
# ..     ...            ...                             ...
# 421   True              1                               4
# 422   True              1                               3
# 423  False              1                               3
# 424   True              1                               4
# 425  False              1                               4
#
#      Принимали ли вы участие в олимпиадах по профильным предметам? / Математика  \
# 0                                                 True
# 1                                                 True
# 2                                                False
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 421                                              False
# 422                                               True
# 423                                              False
# 424                                               True
# 425                                              False
#
#      Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование  \
# 0                                                 True
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 421                                              False
# 422                                               True
# 423                                              False
# 424                                               True
# 425                                               True
#
#      Принимали ли вы участие в олимпиадах по профильным предметам? / Физика  \
# 0                                                False
# 1                                                 True
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 421                                              False
# 422                                              False
# 423                                              False
# 424                                              False
# 425                                              False
#
#      Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 421                                              False
# 422                                              False
# 423                                              False
# 424                                              False
# 425                                              False
#
#      Какие увлечения у вас были, когда вы учились в школе? / Спорт  \
# 0                                                 True
# 1                                                 True
# 2                                                False
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 421                                               True
# 422                                               True
# 423                                              False
# 424                                              False
# 425                                              False
#
#      Какие увлечения у вас были, когда вы учились в школе? / Программирование  \
# 0                                                 True
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 421                                              False
# 422                                              False
# 423                                              False
# 424                                              False
# 425                                               True
#
#      Какие увлечения у вас были, когда вы учились в школе? / Робототехника  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 421                                              False
# 422                                              False
# 423                                              False
# 424                                              False
# 425                                              False
#
#      ...  Аналитика данных  Веб-разработка  \
# 0    ...             False           False
# 1    ...             False           False
# 2    ...             False           False
# 3    ...             False           False
# 4    ...             False           False
# ..   ...               ...             ...
# 421  ...             False           False
# 422  ...             False           False
# 423  ...             False           False
# 424  ...             False           False
# 425  ...             False           False
#
#      Искусственный интеллект и машинное обучение  Кибербезопасность  \
# 0                                           True              False
# 1                                           True              False
# 2                                          False              False
# 3                                          False               True
# 4                                          False              False
# ..                                           ...                ...
# 421                                        False              False
# 422                                         True              False
# 423                                        False               True
# 424                                        False              False
# 425                                        False              False
#
#      Мобильная разработка  Облачные вычисления и DevOps  Разработка UI/UX  \
# 0                   False                         False             False
# 1                   False                         False             False
# 2                    True                         False             False
# 3                   False                         False             False
# 4                   False                         False             False
# ..                    ...                           ...               ...
# 421                 False                         False             False
# 422                 False                         False             False
# 423                 False                         False             False
# 424                 False                         False             False
# 425                 False                         False             False
#
#      Разработка игр  Системное программирование  \
# 0             False                       False
# 1             False                       False
# 2             False                       False
# 3             False                       False
# 4             False                       False
# ..              ...                         ...
# 421            True                       False
# 422           False                       False
# 423           False                       False
# 424           False                        True
# 425            True                       False
#
#                                    target
# 0    Информатика и вычислительная техника
# 1     Биотехнические системы и технологии
# 2    Информатика и вычислительная техника
# 3             Информационная безопасность
# 4     Информационные системы и технологии
# ..                                    ...
# 421  Информатика и вычислительная техника
# 422   Биотехнические системы и технологии
# 423           Информационная безопасность
# 424   Информационные системы и технологии
# 425  Информатика и вычислительная техника
#
# [426 rows x 38 columns]

# %%
data.to_csv('NSTU_Students_data_transformed.csv', index=False)

# %% [markdown]
# # Вариант 2

# %%
data = pd.read_csv('NSTU_Students_data.csv')

# %%
temp.columns
# Out:
# Index(['Пол_Женский', 'Пол_Мужской',
#        'Направление подготовки_Биотехнические системы и технологии',
#        'Направление подготовки_Информатика и вычислительная техника',
#        'Направление подготовки_Информационная безопасность',
#        'Направление подготовки_Информационная безопасность автоматизированных систем',
#        'Направление подготовки_Информационные системы и технологии',
#        'Направление подготовки_Приборостроение',
#        'Направление подготовки_Прикладная информатика',
#        'Направление подготовки_Программная инженерия',
#        'Направление подготовки_Управление в технических системах',
#        'Курс обучения_1 Курс', 'Курс обучения_2 Курс', 'Курс обучения_3 Курс',
#        'Курс обучения_4 Курс', 'Сумма баллов ЕГЭ за 3 предмета_120-150',
#        'Сумма баллов ЕГЭ за 3 предмета_151-200',
#        'Сумма баллов ЕГЭ за 3 предмета_201-230',
#        'Сумма баллов ЕГЭ за 3 предмета_231-260',
#        'Сумма баллов ЕГЭ за 3 предмета_261-300',
#        'Принимали ли вы участие в олимпиадах по профильным предметам? / Математика_Математика',
#        'Принимали ли вы участие в олимпиадах по профильным предметам? / Информатика и программирование_Информатика и программирование',
#        'Принимали ли вы участие в олимпиадах по профильным предметам? / Физика_Физика',
#        'Какие увлечения у вас были, когда вы учились в школе? / Геймдев, VR, AR_Геймдев, VR, AR',
#        'Какие увлечения у вас были, когда вы учились в школе? / Спорт_Спорт',
#        'Какие увлечения у вас были, когда вы учились в школе? / Программирование_Программирование',
#        'Какие увлечения у вас были, когда вы учились в школе? / Робототехника_Робототехника',
#        'Какие увлечения у вас были, когда вы учились в школе? / 3D-моделирование_3D-моделирование',
#        'Какие увлечения у вас были, когда вы учились в школе? / Решение математических задач_Решение математических задач',
#        'Какие увлечения у вас были, когда вы учились в школе? / Творчество: музыка, рисование, танцы и т.п._Творчество: музыка, рисование, танцы и т.п.',
#        'Какие увлечения у вас были, когда вы учились в школе? / Физика_Физика',
#        'Насколько вы любите заниматься ...? / Веб-разработкой_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Веб-разработкой_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Веб-разработкой_Меня это мало интересует',
#        'Насколько вы любите заниматься ...? / Системным администрированием_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Системным администрированием_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Системным администрированием_Меня это мало интересует',
#        'Насколько вы любите заниматься ...? / Математикой_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Математикой_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Математикой_Меня это мало интересует',
#        'Насколько вы любите заниматься ...? / Работой с компьютерным оборудованием и сборкой ПК_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Работой с компьютерным оборудованием и сборкой ПК_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Работой с компьютерным оборудованием и сборкой ПК_Меня это мало интересует',
#        'Насколько вы любите заниматься ...? / Биологией_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Биологией_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Биологией_Меня это мало интересует',
#        'Насколько вы любите заниматься ...? / Аналитикой данных_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Аналитикой данных_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Аналитикой данных_Меня это мало интересует',
#        'Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Разработка графических интерфейсов - GUI_Меня это мало интересует',
#        'Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Написанием серверной части приложений - Back_Меня это мало интересует',
#        'Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Написанием клиентской части приложений - Front_Меня это мало интересует',
#        'Насколько вы любите заниматься ...? / Экономикой и финансами_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Экономикой и финансами_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Экономикой и финансами_Меня это мало интересует',
#        'Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях_Да, это точно про меня!',
#        'Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях_Затрудняюсь ответить',
#        'Насколько вы любите заниматься ...? / Поиском ошибок и уязвимостей на сайтах, в играх или приложениях_Меня это мало интересует',
#        'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?_QA-тестировщик',
#        'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?_Аналитика данных',
#        'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?_Веб-разработка',
#        'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?_Искусственный интеллект и машинное обучение',
#        'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?_Кибербезопасность',
#        'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?_Мобильная разработка',
#        'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?_Облачные вычисления и DevOps',
#        'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?_Разработка UI/UX',
#        'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?_Разработка игр',
#        'Если бы вы могли выбрать только 1 сферу в IT, то что бы выбрали?_Системное программирование',
#        'Вы поступили в университет, потому что сами этого хотели?_Да',
#        'Вы поступили в университет, потому что сами этого хотели?_Нет',
#        'Вам важно получать хорошие отметки?_Да',
#        'Вам важно получать хорошие отметки?_Нет'],
#       dtype='object')
