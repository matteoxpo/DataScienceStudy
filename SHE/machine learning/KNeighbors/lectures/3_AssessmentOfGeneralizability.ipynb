# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Переобучение - когда модель отвечает только на тестовые данные, то есть мы заучили тестовые данные и на реальных данных будет не очень хорошо

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Решение - две выборки, обучающая и тестовая

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
