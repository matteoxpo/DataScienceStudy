# %% [markdown]
# # Ура ура смотрим на это дело через линейную алгебру

# %% [markdown]
# ![image.png](attachment:image.png)<br>
# Всполминим про среднеквадратичную ошибку - нашу метрику<br>
# Мы получается ищем такой w, чтобы MSE был минимальным

# %% [markdown]
# Запишем исходные данные в матричном виде<br>
# ![image.png](attachment:image.png)<br>
# $
# X - матрица признаков, пусть будет обучающей выборкой
# \\
# l - наблюдения
# \\
# d - признаки
# $

# %% [markdown]
# ![image.png](attachment:image.png)<br>
# Вектор да да это матрица где одна из размерностей равна единице<br>
# Запишем следующим видом<br>
# ![image-2.png](attachment:image-2.png)<br>
# Огого надо всего лишь умножить матрицу наблюдений на вектор-столбец $w$<br>
# Делаем вид, что мы еще ничего не поняли<br>
# ![image-3.png](attachment:image-3.png)<br>
# Вторая размерность первой матрицы должна быть равна первой размерности второй матрицы<br>
# Пример на всякий случай<br>
# ![image-4.png](attachment:image-4.png)<br>
# ![image-5.png](attachment:image-5.png)<br>
# И так далее умножаем<br>
# Замечаем все-таки что  $X * w$ в векторном виде это то что надо<br>
# ![image-6.png](attachment:image-6.png)<br>
# Получим вектор столбец скалярных произведений $x_i$ на $w$<br>
# Вернемся к ошибке<br>
# ![image-7.png](attachment:image-7.png)<br>
# Вычислим ее<br>
# ![image-8.png](attachment:image-8.png)<br>
# Вспомним про норму векторного пространства, возьмем Евклидову<br>
# ![image-9.png](attachment:image-9.png)<br>
# По сути это есть длина нашего вектора<br>
# ![image-10.png](attachment:image-10.png)<br>
# То есть мы считаем среднюю длину вектора ошибок<br>
# ![image-11.png](attachment:image-11.png)<br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## А что же делать, если разные размерности количества наблюдений и признаков? Не сходятся размерности для умножения
