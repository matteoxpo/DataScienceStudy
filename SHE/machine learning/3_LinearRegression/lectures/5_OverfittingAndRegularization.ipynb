# %% [markdown]
# Обозначим проблему
# ![image.png](attachment:image.png)
# Видно, что данные плохо моделируются при обычное линейной регрссеии
# Так сделаем модель полиномиальной
# ![image-2.png](attachment:image-2.png)
# Вау полином 4 степени хорошо описывает нашу проблему
# но как-то не идеально
# ![image-3.png](attachment:image-3.png)
# И вот мы подошли к тому, что модель переобучена
# ![image-4.png](attachment:image-4.png)
# Эмперическое^^ наблюдение
# ![image-5.png](attachment:image-5.png)
# Вернемся к задаче угадаем рост по весу
# Видно по кф-ам, что модель переобучена, малейшее изменение признаков приведет к сильным изменениям
# ![image-6.png](attachment:image-6.png)
# Давайте будем давайть штраф за большие веса, добавим регуляризатор
# Посчитаем норму весов (это символ $||w||$)
# ![image-7.png](attachment:image-7.png)
# $\lambda$ - кф, говорящий насколько важно, чтобы веса были небольшими
# Если $\lambda $ большая, то регуляризация будет сильной
# ![image-8.png](attachment:image-8.png)
# Пунт аналитическое решение:
# Добавление матрицы $ \lambda \times ||w||$ сильно повышает шанс того, что конечная матрица будет невырожденной
# Гребневая она потому что $\lambda \times I$ выглядит как гребень, есть еще более сложное графическое объяснение, но не суть
# ![image-9.png](attachment:image-9.png)
# Посмотрим на пример с переобученной моделью, но со штрафами за большие веса
# ![image-10.png](attachment:image-10.png)
# Теперь увеличим кф регуляризации
# ![image-11.png](attachment:image-11.png)
# Она стала еще проще, она стала с большей ошибкой, но график стал прямее
# ![image-12.png](attachment:image-12.png)
# То есть с точки зрения модели лучше иметь небольшие веса, нежели уменьшать MSE, что довольно логично
# W - ГИПЕРПАРАМЕТР!!! то есть подбирается до обучения
# также $w_0$ не участвует в регуляризации
# <br>
# Можно регуляризовать также по-разному
# ![image-13.png](attachment:image-13.png)
# Он может привести к тому, что веса ЗАНУЛЯЮТСЯ
# ![image-14.png](attachment:image-14.png)
# Евклидова норма $L_2$
# Манхетеновская(втф) норма $L_1$
# ![image-15.png](attachment:image-15.png)
