# %% [markdown]
# # PCA алгоритм

# %% [markdown]
# Мы научились считать расстояния до многообразий
# ![image.png](attachment:image.png)
# Все начинается с нульмерного многообразия - берем средний вектор, то есть белая точка на картинке
# Многообразие первого уровня должна проходить через белую точку
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# Ну и как бы прямая крутится вокруг точки и нам надо найти прямую такую, чтобы сумма квадратов векторов была минимальна
# $a_0, a_1$ нашли - как найти $a_2$
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# Посмотрим как в примере должен выглядеть $a_2$
# ![image-6.png](attachment:image-6.png)
# То есть таким образом мы нашли наши "главные" оси для данных, сделали поворот и смещение ДПСК скажем так
# ## Алгоритм
# ![image-7.png](attachment:image-7.png)
# ## Компонентны с максимальной дисперсией
# ![image-8.png](attachment:image-8.png)
# Ищем такую компонентну, что норма ее 1, а сумма квадратов проекций максимальна
# Почему это дисперсия?
# Дисперсия случ величины - мат ожидание квадрата минус квадрат мат ожидания
# Ищем компонентну по которой дисперсия проекция исходных данных максимальна
# Почему?
# Исходные уже центрированы, так как мы вычли $a_0$ который как раз таки является средним, то есть среднее по точкам уже 0
# Итого мы стараемся максимизировать дисперсию(проекции)
# ![image-9.png](attachment:image-9.png)
# *если честно слабо понимаю*
# Так понимаю далее вывод пойдет для всех многообразий
# ![image-10.png](attachment:image-10.png)
# В общем каждый вектор $a_k$ - собственный вектор
# ![image-11.png](attachment:image-11.png)
# Представим что есть 4 точки в 17-мерном пространстве
# И хотим как-то сравнить эти точки:
# ![image-12.png](attachment:image-12.png)
# Найдем главные оси с помощью PCA:
# ![image-13.png](attachment:image-13.png)
# Проекция на 2 главные компоненты
# По сути мы пришли линейными преобразованиями в 2-мерное пространство теряя как можно меньще данных из других пр-ств
# ![image-14.png](attachment:image-14.png)
# То есть суть метода в том, чтобы можно было уменьшить размерность точек с минимизацией потерь данных из других пространств, засчет вот того что мы обсуждали про дисперсию(суть саму я до конца не понял)
# Мы ищем просто новую систему координат, но не применяем нелинейные преобразования
