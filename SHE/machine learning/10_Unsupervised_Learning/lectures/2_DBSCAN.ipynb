# %% [markdown]
# # DBSCAN
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# Посмотрим в примере
# ![image-5.png](attachment:image-5.png)
# * Взяли наугад P2 - в окрестности больше чем надо ура это кор точка
# * Берем любого соседа, допустим P2 - P1
# * Из P1 новых соседей для обхода нет, так что идем к следующему соседу
# * P3 - core точка
# * И далее идем находим все core точки
# Говорим что это кластер, когда закончили с core точками по соседям
# ![image-6.png](attachment:image-6.png)
# * проверяем P6, а соседей нет, так что это noise точка
# ![image-7.png](attachment:image-7.png)
#
# Зачем это придумано
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
