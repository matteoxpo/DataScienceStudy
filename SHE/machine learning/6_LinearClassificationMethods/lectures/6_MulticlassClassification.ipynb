# %% [markdown]
# Ура ура мы умеешь классифицировать между 2 классами
# ![image.png](attachment:image.png)
# А что тут делать?
# ![image-2.png](attachment:image-2.png)
# Мы будем пытаться свести все к задачам, которые мы уже решали
# Например
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# на каждый класс по модели
# Для каждой модели мы строим отдельную обучающую выборку, где будут только объекты класса k
# $a_k$ дает оценку того, что объект $x \in k$
# То есть модель $a_k$ учится разделять $k-ый$ класс от всех остальных
# У нас есть k-моделей, как выбрать одну?
# Мы берем ту модель, где $a_k(x)$ максимально
# Идея простая, но с недостатками
# ![image-5.png](attachment:image-5.png)
# Посмотрим другую модель
# ![image-6.png](attachment:image-6.png)
# Теперь мы берем все пары классов $X_km$
# Тут мы смотрим кто чаще победил в двойке
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# А как оценивать ошибки?
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
