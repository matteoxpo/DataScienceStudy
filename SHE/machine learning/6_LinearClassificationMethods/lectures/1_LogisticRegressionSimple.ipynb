# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# Оцценка - по Х
# Выпустился или нет по оси У
# Данных маловато, поэтому будем говорить в вероятностях
# ![image-4.png](attachment:image-4.png)
# Слева 0, справа 1, а по середине что?
# Не хватает признаков, чтобы опередилть выпустится ли студент или нет
# В общем все сходится к тому, что мы будем говорить в вероятностях
# Посмотрим еще примеры
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# Пример, если модель говорит, что 100 человек вернут кредит с вероятностью 90 процентов, то минимум 90 из 100 должны вернуть кредит
# ![image-9.png](attachment:image-9.png)
# Тут кстати все соответствует
# Ура теперь надо приудмать как это решать
# Вспомним базу
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)
# То есть скалярное произведение не получится использовать как вероятность - решим это!
# ![image-12.png](attachment:image-12.png)
# ![image-13.png](attachment:image-13.png)
# ![image-14.png](attachment:image-14.png)
# Вау вот это да СИГМОИДА помогла
# ![image-15.png](attachment:image-15.png)
# Но опять же сигмоида это один пример...
