# %% [markdown]
# # Обучение с учителем

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# С пересекающимися классами - это когда объект можно классифицировать несколькими типами.<br>
# Например если мы выдаем теги тексту, то может быть несколько тем, которым соответствует текст - классифицировать его по нескольким темам

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Обучение без учителя

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
