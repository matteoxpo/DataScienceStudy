# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Берем ближайшие k соседей и считаем сколько из них относятся к той или иной классификации, затем кого больше - тот и есть наш ответ, наш предикт

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# p = 2 - Евилидовская метрика<br>
# p = 1 - Манхетенская матрика<br>
# можно подпирать разные вообще

# %% [markdown]
# осталось разобраться с РО - функицей подсчета расстояния<br>
# Я так понял там как хочешь так и можешь настроить свое ро

# %% [markdown]
# ![image.png](data:image/png;base64,...)
