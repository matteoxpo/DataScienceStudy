# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Допустим надо угадывать рост человека от его возраста

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Запишем уравнение, которое будет описывать зависимости роста(a) от роста(x)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Пусть X, Y - возраст и длина волос(допустим), Z - рост
# тогда ищем плоскость, которая будет максмально близка ко всем точкам сразу

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# то есть да признака уже<br>
# ![image.png](attachment:image.png)

# %% [markdown]
# в общем все просто, переходим к общему случаю **d-признаков**<br>
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Линейная регрессия сводится к скалярному произведению $<w,x>$ <br>
# ![image.png](attachment:image.png)<br>
# Сделаем допущение<br>
# В векторе x - есть элемент равный 1<br>
# x = ${1,...,x_i,..., x_d}$<br>
# Тогда от $w_0 + <w,x>$ перейдем к $<w,x>$

# %% [markdown]
# Со стороны математики <br>
# ![image.png](attachment:image.png)
# Означает, что мы берем проекцию на нашу гиперплоскость какого-то конкретного значения объекта и выдаем прогноз
