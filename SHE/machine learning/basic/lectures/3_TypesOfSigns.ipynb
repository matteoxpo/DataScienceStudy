# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $u_1, u_2, u_3$ - признаки, которые между собо никак не связаны

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# разновидность категориального признакак - насколько я понял это категориальный признак, который можно сравнивать каким-то определенным образом
