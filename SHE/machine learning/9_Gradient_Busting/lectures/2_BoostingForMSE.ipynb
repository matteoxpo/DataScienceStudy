# %% [markdown]
# ![image.png](attachment:image.png)
# Задача построения $N$-ой модели заключается в построении модели такой, чтобы она уменьшала ошибку
# Давайте рассмотрим ситуацию, когда L - MSE
# ![image-3.png](attachment:image-3.png)
# Перегруппируем - вынесем минус за скобки
# ![image-2.png](attachment:image-2.png)
# Тут по сути мы уже построили $a_{N-1}$, а $y_i$ - константа правильный ответ, добавим обозначение
# ![image-4.png](attachment:image-4.png)
# $s^{(N)}_i = a_{N-1}(x_i) - y_i $ - называют остатками
# По сути с MSE мы сделали подмену целевой переменной
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# В обещм каждая следующая модель компенисурет косяки прошлых
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# Возьмем решающие пни(деревья глубины 1) и посмотрим
# ![image-9.png](attachment:image-9.png)
# Слева визуализация модели, справа остатки
# ![image-10.png](attachment:image-10.png)
# Мы говорили про то, что случайный лес супер и там вообще главное побольше взять количество деревьев
# ![image-11.png](attachment:image-11.png)
# В бустинге не так
# Здесь начиная с какой-то итерации дерево начнет переобучаться:
# ![image-12.png](attachment:image-12.png)
# ![image-13.png](attachment:image-13.png)
