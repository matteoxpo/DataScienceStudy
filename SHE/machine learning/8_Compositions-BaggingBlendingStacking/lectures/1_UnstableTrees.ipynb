# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# Выбросили 10% от выборки
# ![image-4.png](attachment:image-4.png)
# Выбросили другие 10% от выборки
# ![image-5.png](attachment:image-5.png)
# Потом другие 10% выкинули
# ![image-6.png](attachment:image-6.png)
# Деревья сильно зависят от изменений в данных
# Вспомним примеры о усреднении значений каких-то приборов
# ![image-7.png](attachment:image-7.png)
# Ну а тут мы посмотрим за какой класс голосует большинство деревьев и выдаем за ответ
# Итого у нас получится распределение
# ![image-8.png](attachment:image-8.png)
# Теперь другие 10 деревьев для той же выборки, обученгные по-другому
# ![image-9.png](attachment:image-9.png)
# То есть композиция деревье делает их куда более устойчивее
# ![image-10.png](attachment:image-10.png)
