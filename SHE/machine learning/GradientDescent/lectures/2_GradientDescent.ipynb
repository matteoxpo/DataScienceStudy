# %% [markdown]
# Наш выведенный алгоритм градиентного спуска
# ![image.png](attachment:image.png)
# Расмотрим пример
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# Надо как-то проинициализровать веса $w^0$ итерация по $t$
# ![image-5.png](attachment:image-5.png)
# Далее делаем все одно и тоже, спускаясь по градиенту
# $\eta - скорость, размер шага$, но в общем все на рисунке есть
# ![image-6.png](attachment:image-6.png)
# Повторяем пока ???
# Есть несколько условий остановки
# ![image-7.png](attachment:image-7.png)
# Условия остановки
# 1. Когда  $w^t$ почти не менчется
# 2. Если норма/длина вектора градиента близки к нулю
# 3. Можно придумать другие условия установки
# Пример
# Наугад модель построена
# ![image-8.png](attachment:image-8.png)
# Делаем первый шаг
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)
# ![image-12.png](attachment:image-12.png)
# Ура уже смысла итерироваться нет, простой пример с 1 признаком
# Рассмотрим что делать для $d$-штук признаков:
# ![image-13.png](attachment:image-13.png)
# # Итого алгоритм
# ![image-14.png](attachment:image-14.png)
# ## **УСЛОВИЯ ОСТАНОВКИ БЫВАЮТ РАЗНЫЕ**
