# %% [markdown]
# # Пропущенные значения

# %%
import pandas as pd
import numpy as np

bikes = pd.read_pickle('BikesDataVars.pkl')
bikes.head()
# Out:
#         Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0 2017-12-01     0         -5.2        37         2.2       0.0       0.0
# 1 2017-12-01     1         -5.5        38         0.8       0.0       0.0
# 2 2017-12-01     2         -6.0        39         1.0       0.0       0.0
# 3 2017-12-01     3         -6.2        40         0.9       0.0       0.0
# 4 2017-12-01     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 0  Winter        0             True           257                0
# 1  Winter        0             True           219                0
# 2  Winter        0             True           162                0
# 3  Winter        0             True           148                1
# 4  Winter        0             True            97                0
#
#   Temperature Category  Good Weather
# 0             Freezing             0
# 1             Freezing             0
# 2             Freezing             0
# 3             Freezing             0
# 4             Freezing             0

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  8760 non-null   datetime64[ns]
#  1   Hour                  8760 non-null   int64
#  2   Temperature           8581 non-null   float64
#  3   Humidity              8760 non-null   int64
#  4   Wind speed            8760 non-null   float64
#  5   Rainfall              8760 non-null   float64
#  6   Snowfall              8760 non-null   float64
#  7   Seasons               8760 non-null   object
#  8   Holiday               8760 non-null   int64
#  9   Functioning Day       8760 non-null   bool
#  10  Rental Count          8760 non-null   int64
#  11  Normal Humidity       8760 non-null   int64
#  12  Temperature Category  8581 non-null   category
#  13  Good Weather          8760 non-null   int64
# dtypes: bool(1), category(1), datetime64[ns](1), float64(4), int64(6), object(1)
# memory usage: 838.5+ KB

# %%
bikes.isna().sum()
# Out:
# Date                      0
# Hour                      0
# Temperature             179
# Humidity                  0
# Wind speed                0
# Rainfall                  0
# Snowfall                  0
# Seasons                   0
# Holiday                   0
# Functioning Day           0
# Rental Count              0
# Normal Humidity           0
# Temperature Category    179
# Good Weather              0
# dtype: int64

# %%
bikes[bikes['Temperature'].isna()].shape
# Out:
# (179, 14)

# %%
bikes[bikes['Temperature'].isna()]['Temperature']
# Out:
# 39     NaN
# 50     NaN
# 64     NaN
# 105    NaN
# 151    NaN
#         ..
# 8669   NaN
# 8679   NaN
# 8710   NaN
# 8717   NaN
# 8742   NaN
# Name: Temperature, Length: 179, dtype: float64

# %%
type(bikes[bikes['Temperature'].isna()]['Temperature'][50])
# Out:
# numpy.float64

# %%
bikes[bikes['Temperature'].notna()].shape
# Out:
# (8581, 14)

# %%
bikes.dropna(subset=['Temperature']).shape
# Out:
# (8581, 14)

# %%
bikes['Temperature_Median'] = bikes['Temperature'].fillna(42)

# %%
bikes[bikes['Temperature'].isna()].head()
# Out:
#           Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 39  2017-12-02    15          NaN        41         2.3       0.0       0.0
# 50  2017-12-03     2          NaN        79         1.4       0.0       0.0
# 64  2017-12-03    16          NaN        77         1.6       0.0       0.0
# 105 2017-12-05     9          NaN        31         1.3       0.0       0.0
# 151 2017-12-07     7          NaN        93         0.5       0.0       0.9
#
#     Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 39   Winter        0             True           688                1
# 50   Winter        0             True           262                0
# 64   Winter        0             True           577                0
# 105  Winter        0             True           313                0
# 151  Winter        0             True           269                0
#
#     Temperature Category  Good Weather  Temperature_Median
# 39                   NaN             0                42.0
# 50                   NaN             0                42.0
# 64                   NaN             0                42.0
# 105                  NaN             0                42.0
# 151                  NaN             0                42.0

# %%
bikes['Temperature_Median'] = bikes['Temperature'].fillna(bikes['Temperature'].median())

# %%
bikes[bikes['Temperature'].isna()].head()
# Out:
#           Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 39  2017-12-02    15          NaN        41         2.3       0.0       0.0
# 50  2017-12-03     2          NaN        79         1.4       0.0       0.0
# 64  2017-12-03    16          NaN        77         1.6       0.0       0.0
# 105 2017-12-05     9          NaN        31         1.3       0.0       0.0
# 151 2017-12-07     7          NaN        93         0.5       0.0       0.9
#
#     Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 39   Winter        0             True           688                1
# 50   Winter        0             True           262                0
# 64   Winter        0             True           577                0
# 105  Winter        0             True           313                0
# 151  Winter        0             True           269                0
#
#     Temperature Category  Good Weather  Temperature_Median
# 39                   NaN             0                13.7
# 50                   NaN             0                13.7
# 64                   NaN             0                13.7
# 105                  NaN             0                13.7
# 151                  NaN             0                13.7

# %%
bikes.iloc[38:42]
# Out:
#          Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 38 2017-12-02    14          7.3        35         1.3       0.0       0.0
# 39 2017-12-02    15          NaN        41         2.3       0.0       0.0
# 40 2017-12-02    16          6.4        48         2.6       0.0       0.0
# 41 2017-12-02    17          6.0        51         2.5       0.0       0.0
#
#    Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 38  Winter        0             True          1054                0
# 39  Winter        0             True           688                1
# 40  Winter        0             True           592                1
# 41  Winter        0             True           141                1
#
#    Temperature Category  Good Weather  Temperature_Median
# 38               Chilly             0                 7.3
# 39                  NaN             0                13.7
# 40               Chilly             0                 6.4
# 41               Chilly             0                 6.0

# %%
# hot deck imputation
np.random.choice(bikes['Temperature'].dropna())
# Out:
# 3.8

# %%
bikes['Temperature_Random'] = bikes['Temperature'].fillna(np.random.choice(bikes['Temperature'].dropna()))
bikes[bikes['Temperature'].isna()].head()
# Out:
#           Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 39  2017-12-02    15          NaN        41         2.3       0.0       0.0
# 50  2017-12-03     2          NaN        79         1.4       0.0       0.0
# 64  2017-12-03    16          NaN        77         1.6       0.0       0.0
# 105 2017-12-05     9          NaN        31         1.3       0.0       0.0
# 151 2017-12-07     7          NaN        93         0.5       0.0       0.9
#
#     Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 39   Winter        0             True           688                1
# 50   Winter        0             True           262                0
# 64   Winter        0             True           577                0
# 105  Winter        0             True           313                0
# 151  Winter        0             True           269                0
#
#     Temperature Category  Good Weather  Temperature_Median  Temperature_Random
# 39                   NaN             0                13.7                 3.5
# 50                   NaN             0                13.7                 3.5
# 64                   NaN             0                13.7                 3.5
# 105                  NaN             0                13.7                 3.5
# 151                  NaN             0                13.7                 3.5

# %%
bikes.shape
# Out:
# (8760, 16)

# %%
temps = np.random.choice(bikes['Temperature'].dropna(), bikes.shape[0])
temps[:100]
# Out:
# array([ 20.2,  15.7,  29.8,  21.8,  17.1,  21.2,  19.4,   3. ,  11.8,
#          4.2,   8.9,  23.6,   0.3,  -2.3,  16.2,  25. ,   6.9,  -7.7,
#         10.6,  16.2,  15. ,   0.1,   9.8,  16.9,  26.3,  26.6,  -4.3,
#        -10.3,  16.7,  26.1,   8.5,   9.6,  21.5,  -4.7,   9.5,  29.4,
#         24.5,   6. ,  20.1,  20.2,   2.9,  21.2,   8.8,  30.8,   1.2,
#         -9.4,   5.3,  10.6,  -5.8,  17.1,  30.4,   0.6,  -1.6,   1.3,
#         21.3,  18.5, -11.6,  16.5,  24.5,  24.1,  18. ,  21.9,  14.8,
#         21.6,  10. ,  18.2,  -0.8,  25. ,  29.8,  25.1,  24.6,  23.9,
#         31.3,  21.2, -14.1,   4.7,  23.5,  -8.5,  22.5,  26.6,   6.2,
#         11.5,  11.2,   2.4, -10.2,  13.9,   4.8,   1.6,  -6.9,  12.1,
#         22.9,  17.4,  24.1,  23.2,  26. ,  15.7,  11.1,  21.1,  32.4,
#         19.7])

# %%
bikes['Temperature_Random'] = bikes['Temperature'].fillna(pd.Series(temps))

# %%
bikes[bikes['Temperature'].isna()].head()
# Out:
#           Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 39  2017-12-02    15          NaN        41         2.3       0.0       0.0
# 50  2017-12-03     2          NaN        79         1.4       0.0       0.0
# 64  2017-12-03    16          NaN        77         1.6       0.0       0.0
# 105 2017-12-05     9          NaN        31         1.3       0.0       0.0
# 151 2017-12-07     7          NaN        93         0.5       0.0       0.9
#
#     Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 39   Winter        0             True           688                1
# 50   Winter        0             True           262                0
# 64   Winter        0             True           577                0
# 105  Winter        0             True           313                0
# 151  Winter        0             True           269                0
#
#     Temperature Category  Good Weather  Temperature_Median  Temperature_Random
# 39                   NaN             0                13.7                20.2
# 50                   NaN             0                13.7                30.4
# 64                   NaN             0                13.7                10.0
# 105                  NaN             0                13.7                 0.2
# 151                  NaN             0                13.7                11.3

# %%
bikes.iloc[38:42]
# Out:
#          Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 38 2017-12-02    14          7.3        35         1.3       0.0       0.0
# 39 2017-12-02    15          NaN        41         2.3       0.0       0.0
# 40 2017-12-02    16          6.4        48         2.6       0.0       0.0
# 41 2017-12-02    17          6.0        51         2.5       0.0       0.0
#
#    Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 38  Winter        0             True          1054                0
# 39  Winter        0             True           688                1
# 40  Winter        0             True           592                1
# 41  Winter        0             True           141                1
#
#    Temperature Category  Good Weather  Temperature_Median  Temperature_Random
# 38               Chilly             0                 7.3                 7.3
# 39                  NaN             0                13.7                20.2
# 40               Chilly             0                 6.4                 6.4
# 41               Chilly             0                 6.0                 6.0

# %%
bikes.groupby([bikes['Date'].dt.isocalendar().week, 'Hour'])['Temperature'].median()
# Out:
# week  Hour
# 1     0      -4.3
#       1      -4.8
#       2      -5.3
#       3      -5.5
#       4      -5.1
#              ...
# 52    19     -0.4
#       20     -1.0
#       21     -1.6
#       22     -1.7
#       23     -1.0
# Name: Temperature, Length: 1248, dtype: float64

# %%
temp_medians = bikes.groupby([bikes['Date'].dt.isocalendar().week, 'Hour'])['Temperature'].median()

# %%
temp_medians = bikes.groupby([bikes['Date'].dt.isocalendar().week, 'Hour'])['Temperature'].transform("median")

# %%
bikes['Temperature_Median_Group'] = bikes['Temperature'].fillna(pd.Series(temp_medians))
bikes[bikes['Temperature'].isna()].head()
# Out:
#           Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 39  2017-12-02    15          NaN        41         2.3       0.0       0.0
# 50  2017-12-03     2          NaN        79         1.4       0.0       0.0
# 64  2017-12-03    16          NaN        77         1.6       0.0       0.0
# 105 2017-12-05     9          NaN        31         1.3       0.0       0.0
# 151 2017-12-07     7          NaN        93         0.5       0.0       0.9
#
#     Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 39   Winter        0             True           688                1
# 50   Winter        0             True           262                0
# 64   Winter        0             True           577                0
# 105  Winter        0             True           313                0
# 151  Winter        0             True           269                0
#
#     Temperature Category  Good Weather  Temperature_Median  \
# 39                   NaN             0                13.7
# 50                   NaN             0                13.7
# 64                   NaN             0                13.7
# 105                  NaN             0                13.7
# 151                  NaN             0                13.7
#
#      Temperature_Random  Temperature_Median_Group
# 39                 20.2                      7.50
# 50                 30.4                      1.35
# 64                 10.0                      7.20
# 105                 0.2                     -2.40
# 151                11.3                     -4.85

# %%
bikes.iloc[38:42]
# Out:
#          Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 38 2017-12-02    14          7.3        35         1.3       0.0       0.0
# 39 2017-12-02    15          NaN        41         2.3       0.0       0.0
# 40 2017-12-02    16          6.4        48         2.6       0.0       0.0
# 41 2017-12-02    17          6.0        51         2.5       0.0       0.0
#
#    Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 38  Winter        0             True          1054                0
# 39  Winter        0             True           688                1
# 40  Winter        0             True           592                1
# 41  Winter        0             True           141                1
#
#    Temperature Category  Good Weather  Temperature_Median  Temperature_Random  \
# 38               Chilly             0                 7.3                 7.3
# 39                  NaN             0                13.7                20.2
# 40               Chilly             0                 6.4                 6.4
# 41               Chilly             0                 6.0                 6.0
#
#     Temperature_Median_Group
# 38                       7.3
# 39                       7.5
# 40                       6.4
# 41                       6.0

# %%
bikes.iloc[102:107]
# Out:
#           Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 102 2017-12-05     6         -7.4        34         3.2       0.0       0.0
# 103 2017-12-05     7         -7.5        33         2.2       0.0       0.0
# 104 2017-12-05     8         -8.1        36         1.6       0.0       0.0
# 105 2017-12-05     9          NaN        31         1.3       0.0       0.0
# 106 2017-12-05    10         -5.5        26         2.8       0.0       0.0
#
#     Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 102  Winter        0             True           174                0
# 103  Winter        0             True           494                0
# 104  Winter        0             True           191                0
# 105  Winter        0             True           313                0
# 106  Winter        0             True            62                0
#
#     Temperature Category  Good Weather  Temperature_Median  \
# 102             Freezing             0                -7.4
# 103             Freezing             0                -7.5
# 104             Freezing             0                -8.1
# 105                  NaN             0                13.7
# 106             Freezing             0                -5.5
#
#      Temperature_Random  Temperature_Median_Group
# 102                -7.4                      -7.4
# 103                -7.5                      -7.5
# 104                -8.1                      -8.1
# 105                 0.2                      -2.4
# 106                -5.5                      -5.5

# %%
bikes = pd.read_pickle('BikesDataVars.pkl')
bikes['Temperature'] = bikes['Temperature'].fillna(pd.Series(temp_medians))

# %%
def get_temp_cat(temp):
    if temp < 0:
        return 'Freezing'
    elif temp < 15:
        return 'Chilly'
    elif temp < 26:
        return 'Nice'
    elif temp >= 26:
        return 'Hot'
    else:
        return temp

bikes['Temperature Category'] = pd.Categorical(bikes['Temperature'].apply(get_temp_cat))

# %%
bikes.to_pickle('BikesDataImputed.pkl')
