# %% [markdown]
# # Меры разброса

# %%
# импортируем модуль os
import os

# выводим пути к папкам (dirpath) и наименования файлов (filenames) и после этого
for dirpath, _, filenames in os.walk('/content/'):

  # во вложенном цикле проходимся по названиям файлов
  for filename in filenames:

    # и соединяем путь до папок и входящие в эти папки файлы
    # с помощью метода path.join()
    print(os.path.join(dirpath, filename))
# Out:
# /content/MarvelComicCaracters.csv
# /content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# /content/.config/default_configs.db
# /content/.config/active_config
# /content/.config/.last_update_check.json
# /content/.config/config_sentinel
# /content/.config/.last_survey_prompt.yaml
# /content/.config/.last_opt_in_prompt.yaml
# /content/.config/gce
# /content/.config/logs/2024.08.14/13.22.33.722243.log
# /content/.config/logs/2024.08.14/13.22.46.371791.log
# /content/.config/logs/2024.08.14/13.22.34.768835.log
# /content/.config/logs/2024.08.14/13.22.45.672555.log
# /content/.config/logs/2024.08.14/13.22.22.289783.log
# /content/.config/logs/2024.08.14/13.22.01.192536.log
# /content/.config/configurations/config_default
# /content/sample_data/README.md
# /content/sample_data/anscombe.json
# /content/sample_data/mnist_train_small.csv
# /content/sample_data/california_housing_test.csv
# /content/sample_data/mnist_test.csv
# /content/sample_data/california_housing_train.csv

# %%
# !ls
# Out:
# MarvelComicCaracters.csv  sample_data

# %%
import pandas as pd
import numpy as np

marvel = pd.read_csv('MarvelComicCaracters.csv', sep=';')
marvel.head()
# Out:
#                                   name                 align            eye  \
# 0            Spider-Man (Peter Parker)       Добрый персонаж    Карие глаза
# 1      Captain America (Steven Rogers)       Добрый персонаж  Голубые глаза
# 2  Wolverine (James \"Logan\" Howlett)  Нейтральный персонаж  Голубые глаза
# 3    Iron Man (Anthony \"Tony\" Stark)       Добрый персонаж  Голубые глаза
# 4                  Thor (Thor Odinson)       Добрый персонаж  Голубые глаза
#
#                 hair               sex  appearances  first_appearance
# 0  Каштановые волосы  Мужской персонаж       4043.0            1962.0
# 1       Белые волосы  Мужской персонаж       3360.0            1941.0
# 2      Черные волосы  Мужской персонаж       3061.0            1974.0
# 3      Черные волосы  Мужской персонаж       2961.0            1963.0
# 4       Русые волосы  Мужской персонаж       2258.0            1950.0

# %%
marvel[marvel["sex"] == "Женский персонаж"]["hair"].mode()
# Out:
# 0    Черные волосы
# Name: hair, dtype: object

# %%
marvel[marvel["sex"] == "Мужской персонаж"]["hair"].mode()
# Out:
# 0    Черные волосы
# Name: hair, dtype: object

# %%
marvel["align"].unique()
# Out:
# array(['Добрый персонаж', 'Нейтральный персонаж', 'Злой персонаж', nan],
#       dtype=object)

# %%
marvel[marvel["align"] == "Злой персонаж"]["appearances"].median()
# Out:
# 3.0

# %%
marvel["appearances"].var(ddof=0)
# Out:
# 9287.139461894549

# %%
marvel["first_appearance"].mode()
# Out:
# 0    1993.0
# Name: first_appearance, dtype: float64

# %%
marvel["first_appearance"].value_counts()
# Out:
# first_appearance
# 1993.0    554
# 1994.0    485
# 1992.0    455
# 2006.0    381
# 2008.0    360
#          ...
# 1952.0     26
# 1956.0     16
# 1957.0      7
# 1959.0      4
# 1958.0      2
# Name: count, Length: 75, dtype: int64

# %%
len(marvel)
# Out:
# 16376

# %%
clear = marvel.iloc[500:]
clear['eye'].mode()
# Out:
# 0    Темно-карие глаза
# Name: eye, dtype: object

# %%
hair_mode = marvel['hair'].mode()[0]
hair_mode
# Out:
# 'Черные волосы'

# %%
filtered = marvel[marvel['hair'] == hair_mode]
filtered['appearances'].std(ddof=0)
# Out:
# 94.13253937689814

# %%
bikes_hour.plot(kind='bar')

# %%
bikes_hour.describe()

# %%
# размах
bikes_hour['Rental Count'].max() - bikes_hour['Rental Count'].min()

# %%
# интерквартильный размах
bikes_hour['Rental Count'].quantile(0.75) - bikes_hour['Rental Count'].quantile(0.25)

# %%
# перцентили
print(np.percentile(bikes_hour['Rental Count'], 25))
print(np.quantile(bikes_hour['Rental Count'], 0.25))

# %%
bikes_mean = bikes_hour['Rental Count'].mean()
deviations = bikes_hour['Rental Count'] - bikes_mean
sq_deviations = deviations ** 2
variance_samp = sq_deviations.sum() / (len(bikes_hour) - 1)
std_samp = np.sqrt(variance_samp)
print(variance_samp)
print(std_samp)

# %%
print(bikes_hour['Rental Count'].var())
print(np.sqrt(bikes_hour['Rental Count'].var()))
print(bikes_hour['Rental Count'].std())

# %%
variance_pop = sq_deviations.sum() / (len(bikes_hour))
print(variance_pop)
print(np.sqrt(variance_pop))

# %%
print(bikes_hour['Rental Count'].var(ddof=0))
print(bikes_hour['Rental Count'].std(ddof=0))

# %%
bikes.groupby('Hour')['Rental Count'].std()

# %%
bikes.groupby('Hour')['Rental Count'].agg(['mean', 'std'])

# %%
def range_values(x):
    return x.max() - x.min()

bikes.pivot_table(index='Hour',
                  values=['Temperature', 'Rental Count'],
                  aggfunc=['mean', 'std', 'var', range_values])
