# %% [markdown]
# # Меры разброса

# %% [markdown]
# 1.33 + 2.12 * X + 0.23 * 1 - (1.33 + 2.12 * X)= 0.23

# %% [markdown]
# 2.12 * (X+1 - X) = 2.12

# %% [markdown]
# y = 1.33 + 2.12 * X + 0.23 * Z<br>
# X = 5<br>
# Z = 0<br>
# y = 1.33 + 2.12 * 5<br>
# <br>

# %%
import math
y = 1.33 + 2.12 * 5
print(y)
p = 1 / (1 + math.exp(-y))
print(round(p,2))
# Out:
# 11.930000000000001
# 1.0
